# %% [markdown]
# # Information Retreval

# %% [markdown]
# ## Table of Contents
# <ul>
#     <li><a href="#read_files">Read Files</a></li>
#     <li><a href="#regularisation">Regularisation</a></li>
#     <li>
#     <a href="#tokenization_normalization">Tokenization and normalization</a>
#         <ul>
#             <li> <a href="#tokenization">Tokenization</a></li>
#             <li> <a href="#stop_word_removal">Stop word removal</a></li>
#         </ul>
#     </li>
#     <li>
#     <a href="#positioal_index_model">Positioal index model</a>
#         <ul>
#             <li> <a href="#constructing_auxiliary">Constructing Auxiliary structure(s) </a></li>
#             <li> <a href="#Phrase_query">Phrase query</a></li>
#         </ul>
#     </li>
#     <li>
#     <a href="#vector_space_model">Vector space model</a>
#         <ul>
#             <li> <a href="#term_frequency">Term frequency </a></li>
#             <li> <a href="#idf">inverse document frequency</a></li>
#             <li> <a href="#tf_idf_matrix">TF.idf matrix </a></li>
#             <li> <a href="#Similarity">Similarity between query and each document </a></li>
#         </ul>
#     </li>
# </ul>

# %%
# from nltk.corpus import stopwords
# from nltk.tokenize import sent_tokenize, word_tokenize
# from nltk.cluster.util import cosine_distance
# import nltk
import numpy as np
import pandas as pd
import os
import re

# %% [markdown]
# <a id='read_files'></a>
# ## Read Files

# %%
encoding="utf8"
docPaths = os.listdir("documents")
documentList = []
for docName in docPaths:
    with open("documents/"+docName,"r",encoding=encoding) as file:
        if file.mode == 'r':
            documentList.append(file.read())

# %% [markdown]
# <a id='regularisation'></a>
# ## regularisation

# %%
for i in range(10):
#     documentList[i] = re.sub(r'\n|“|”|\.|\'|,', '', document)#Removing punctuation
    documentList[i] = re.sub(r'’', '\'', documentList[i])  # Replace ’ With '
    documentList[i] = re.sub(r'“', '"', documentList[i])   # Replace “ With "
    documentList[i] = re.sub(r'”', '"', documentList[i])   # Replace ” With "
    documentList[i] = re.sub(r',', ',', documentList[i])   # Replace , With ,

# %%
documentList[9]
# Out:
# 'Ms. Groves had originally sent the video, in which she looked into the camera and said, "I can drive," followed by the slur, to a friend on Snapchat in 2016, when she was a freshman and had just gotten her learner\'s permit. It later circulated among some students at Heritage High School, which she and Mr. Galligan attended, but did not cause much of a stir.\n\nMr. Galligan had not seen the video before receiving it last school year, when he and Ms. Groves were seniors. By then, she was a varsity cheer captain who dreamed of attending the University of Tennessee, Knoxville, whose cheer team was the reigning national champion. When she made the team in May, her parents celebrated with a cake and orange balloons, the university\'s official color.\n\nThe next month, as protests were sweeping the nation after the police killing of George Floyd, Ms. Groves, in a public Instagram post, urged people to "protest, donate, sign a petition, rally, do something" in support of the Black Lives Matter movement.access to cloud and AI services. As part of the program, the Redmond giant which wants to expand its reach and is planning to build a strong developer ecosystem in India with the program will set up the core AI infrastructure and IoT Hub for the selected campuses. The company will provide AI development tools and Azure AI services such as Microsoft Cognitive Services, Bot Services and Azure Machine Learning.According to Manish Prakash, Country General Manager-PS, Health and Education, Microsoft India, said, "With AI being the defining technology of our time, it is transforming lives and industry and the jobs of tomorrow will require a different skillset. This will require more collaborations and training and working with AI'

# %% [markdown]
# <a id='tokenization_normalization'></a>
# ## Tokenization and normalization

# %% [markdown]
# <a id='tokenization'></a>
# > ### Tokenization

# %%
from nltk.tokenize import regexp_tokenize

# %%
tokenized_documentList = []
for document in documentList:
    tokenized_documentList.append( regexp_tokenize(document, "[\w']+") )

# %%
tokenized_documentList
# Out:
# [['The',
#   'Perdue',
#   'campaign',
#   'did',
#   'not',
#   'respond',
#   'to',
#   "CNN's",
#   'inquiries',
#   'about',
#   'the',
#   'status',
#   'of',
#   'their',
#   'ad',
#   'on',
#   'Saturday',
#   'and',
#   'they',
#   'once',
#   'again',
#   'ignored',
#   'questions',
#   'about',
#   'where',
#   'the',
#   'senator',
#   'stands',
#   'on',
#   "Trump's",
#   'calls',
#   'for',
#   'changes',
#   'to',
#   'the',
#   'bill',
#   'At',
#   'a',
#   'news',
#   'conference',
#   'on',
#   'Wednesday',
#   'Loeffler',
#   'said',
#   'she',
#   'would',
#   'be',
#   'open',
#   'to',
#   'the',
#   'idea',
#   'of',
#   'bigger',
#   'checks',
#   'but',
#   'argued',
#   'that',
#   'other',
#   'parts',
#   'of',
#   'the',
#   'package',
#   'would',
#   'have',
#   'to',
#   'be',
#   'cut',
#   'in',
#   'order',
#   'to',
#   'accommodate',
#   'the',
#   'expense',
#   "Trump's",
#   'mixed',
#   'signals',
#   'on',
#   'the',
#   'relief',
#   'bill',
#   'are',
#   'just',
#   'one',
#   'example',
#   'of',
#   'how',
#   'his',
#   'erratic',
#   'behavior',
#   'during',
#   'the',
#   'waning',
#   'days',
#   'of',
#   'his',
#   'presidency',
#   'is',
#   'interrupting',
#   'the',
#   'careful',
#   'messaging',
#   'Republicans',
#   'are',
#   'trying',
#   'to',
#   'craft',
#   'as',
#   'they',
#   'fight',
#   'to',
#   'hold',
#   'onto',
#   'these',
#   'two',
#   'seats',
#   'and',
#   'retain',
#   'control',
#   'of',
#   'the',
#   'majority',
#   'in',
#   'the',
#   'US',
#   'Senate',
#   'Trump',
#   'last',
#   'week',
#   'vetoed',
#   'the',
#   'National',
#   'Defense',
#   'Authorization',
#   'Act',
#   'which',
#   'was',
#   'legislation',
#   'Loeffler',
#   'and',
#   'Perdue',
#   'both',
#   'supported',
#   'setting',
#   'up',
#   'the',
#   'first',
#   'possible',
#   'veto',
#   'override',
#   'of',
#   'his',
#   'presidency',
#   'Trump',
#   'also',
#   'continues',
#   'to',
#   'undermine',
#   'the',
#   'voting',
#   'system',
#   'in',
#   'Georgia',
#   'and',
#   'relentlessly',
#   'attack',
#   'the',
#   'Republican',
#   'leaders',
#   'who',
#   'administered',
#   'the',
#   'November',
#   'election',
#   'in',
#   'the',
#   'state',
#   'which',
#   'he',
#   'lost',
#   'to',
#   'President',
#   'elect',
#   'Joe',
#   'Biden',
#   'His',
#   'rhetoric',
#   'has',
#   'left',
#   'the',
#   'GOP',
#   'in',
#   'the',
#   'difficult',
#   'spot',
#   'of',
#   'begging',
#   'his',
#   'supporters',
#   'to',
#   'come',
#   'out',
#   'and',
#   'vote',
#   'in',
#   'the',
#   'two',
#   'runoffs',
#   'on',
#   'January',
#   '5',
#   'while',
#   'at',
#   'the',
#   'same',
#   'time',
#   'entertaining',
#   'his',
#   'baseless',
#   'claims',
#   'that',
#   'the',
#   'voting',
#   'system',
#   'there',
#   'is',
#   'rife',
#   'with',
#   'fraud'],
#  ['In',
#   'an',
#   'attempt',
#   'to',
#   'build',
#   'an',
#   'AI',
#   'ready',
#   'workforce',
#   'Microsoft',
#   'announced',
#   'Intelligent',
#   'Cloud',
#   'Hub',
#   'which',
#   'has',
#   'been',
#   'launched',
#   'to',
#   'empower',
#   'the',
#   'next',
#   'generation',
#   'of',
#   'students',
#   'with',
#   'AI',
#   'ready',
#   'skills',
#   'Envisioned',
#   'as',
#   'a',
#   'three',
#   'year',
#   'collaborative',
#   'program',
#   'Intelligent',
#   'Cloud',
#   'Hub',
#   'will',
#   'support',
#   'around',
#   '100',
#   'institutions',
#   'with',
#   'AI',
#   'infrastructure',
#   'course',
#   'content',
#   'and',
#   'curriculum',
#   'developer',
#   'support',
#   'development',
#   'tools',
#   'and',
#   'give',
#   'students',
#   'access',
#   'to',
#   'cloud',
#   'and',
#   'AI',
#   'services',
#   'As',
#   'part',
#   'of',
#   'the',
#   'program',
#   'the',
#   'Redmond',
#   'giant',
#   'which',
#   'wants',
#   'to',
#   'expand',
#   'its',
#   'reach',
#   'and',
#   'is',
#   'planning',
#   'to',
#   'build',
#   'a',
#   'strong',
#   'developer',
#   'ecosystem',
#   'in',
#   'India',
#   'with',
#   'the',
#   'program',
#   'will',
#   'set',
#   'up',
#   'the',
#   'core',
#   'AI',
#   'but',
#   'that',
#   'could',
#   'be',
#   'because',
#   'the',
#   'US',
#   'surveillance',
#   'system',
#   'established',
#   'infrastructure',
#   'and',
#   'IoT',
#   'Hub',
#   'for',
#   'the',
#   'selected',
#   'campuses',
#   'The',
#   'company',
#   'will',
#   'provide',
#   'AI',
#   'development',
#   'tools',
#   'and',
#   'Azure',
#   'AI',
#   'services',
#   'such',
#   'as',
#   'photo',
#   'of',
#   'Jordan',
#   'and',
#   'an',
#   'opposing',
#   'player',
#   'Microsoft',
#   'Cognitive',
#   'Services',
#   'Bot',
#   'Services',
#   'and',
#   'Azure',
#   'Machine',
#   'Learning',
#   'According',
#   'to',
#   'Manish',
#   'Prakash',
#   'Country',
#   'General',
#   'Manager',
#   'PS',
#   'Health',
#   'and',
#   'Education',
#   'Microsoft',
#   'India',
#   'said',
#   'With',
#   'AI',
#   'being',
#   'the',
#   'defining',
#   'technology',
#   'of',
#   'our',
#   'time',
#   'it',
#   'is',
#   'transforming',
#   'lives',
#   'and',
#   'industry',
#   'and',
#   'the',
#   'jobs',
#   'of',
#   'tomorrow',
#   'will',
#   'require',
#   'a',
#   'different',
#   'skillset',
#   'This',
#   'will',
#   'require',
#   'more',
#   'collaborations',
#   'federal',
#   'loans',
#   'for',
#   'small',
#   'businesses',
#   "won't",
#   'and',
#   'training',
#   'and',
#   'working',
#   'with',
#   'AI',
#   "That's",
#   'why',
#   'it',
#   'has',
#   'become',
#   'more',
#   'critical',
#   'than',
#   'ever',
#   'for',
#   'educational',
#   'institutions',
#   'to',
#   'integrate',
#   'new',
#   'cloud',
#   'and',
#   'AI',
#   'technologies',
#   'The',
#   'program',
#   'is',
#   'an',
#   'attempt',
#   'to',
#   'challenge',
#   'the',
#   'election',
#   'results',
#   'ramp',
#   'up',
#   'the',
#   'institutional',
#   'set',
#   'up',
#   'and',
#   'build',
#   'capabilities',
#   'among',
#   'the',
#   'educators',
#   'to',
#   'educate',
#   'the',
#   'workforce',
#   'of',
#   'tomorrow',
#   'The',
#   'program',
#   'aims',
#   'to',
#   'build',
#   'up',
#   'the',
#   'cognitive',
#   'skills',
#   'and',
#   'onto',
#   'power',
#   'looked',
#   'increasingly',
#   'in',
#   'depth',
#   'understanding',
#   'of',
#   'developing',
#   'intelligent',
#   'cloud',
#   'connected',
#   'solutions',
#   'for',
#   'applications',
#   'across',
#   'industry',
#   'Earlier',
#   'in',
#   'April',
#   'this',
#   'year',
#   'the',
#   'company',
#   'announced',
#   'Microsoft',
#   'Professional',
#   'Program',
#   'In',
#   'AI',
#   'as',
#   'a',
#   'learning',
#   'track',
#   'open',
#   'to',
#   'the',
#   'public',
#   'The',
#   'program',
#   'was',
#   'developed',
#   'to',
#   'provide',
#   'job',
#   'ready',
#   'skills',
#   'to',
#   'programmers',
#   'who',
#   'wanted',
#   'to',
#   'hone',
#   'their',
#   'skills',
#   'in',
#   'AI',
#   'and',
#   'data',
#   'science',
#   'with',
#   'a',
#   'series',
#   'of',
#   'online',
#   'courses',
#   'which',
#   'featured',
#   'hands',
#   'on',
#   'labs',
#   'and',
#   'expert',
#   'instructors',
#   'as',
#   'well',
#   'This',
#   'program',
#   'also',
#   'included',
#   'developer',
#   'focused',
#   'AI',
#   'school',
#   'that',
#   'provided',
#   'a',
#   'bunch',
#   'of',
#   'assets',
#   'to',
#   'help',
#   'build',
#   'AI',
#   'skills',
#   'The',
#   'next',
#   'month'],
#  ['A',
#   'method',
#   'assigns',
#   'importance',
#   'ranks',
#   'to',
#   'nodes',
#   'in',
#   'a',
#   'linked',
#   'database',
#   'such',
#   'as',
#   'any',
#   'database',
#   'of',
#   'documents',
#   'containing',
#   'citations',
#   'the',
#   'world',
#   'wide',
#   'web',
#   'or',
#   'any',
#   'other',
#   'hypermedia',
#   'database',
#   'The',
#   'rank',
#   'assigned',
#   'to',
#   'a',
#   'document',
#   'is',
#   'calculated',
#   'from',
#   'the',
#   'ranks',
#   'of',
#   'documents',
#   'citing',
#   'it',
#   'In',
#   'addition',
#   'the',
#   'rank',
#   'of',
#   'a',
#   'document',
#   'is',
#   'calculated',
#   'from',
#   'a',
#   'constant',
#   'representing',
#   'the',
#   'probability',
#   'that',
#   'a',
#   'browser',
#   'through',
#   'the',
#   'database',
#   'will',
#   'randomly',
#   'jump',
#   'to',
#   'the',
#   'document',
#   'The',
#   'method',
#   'is',
#   'particularly',
#   'useful',
#   'in',
#   'enhancing',
#   'the',
#   'performance',
#   'of',
#   'search',
#   'engine',
#   'results',
#   'for',
#   'hypermedia',
#   'databases',
#   'such',
#   'as',
#   'the',
#   'number',
#   'of',
#   'felonies',
#   'including',
#   'fraud',
#   'and',
#   'money',
#   'laundering',
#   'world',
#   'wide',
#   'web',
#   'whose',
#   'documents',
#   'have',
#   'a',
#   'large',
#   'variation',
#   'in',
#   'quality',
#   'planning',
#   'to',
#   'build',
#   'a',
#   'strong',
#   'developer',
#   'ecosystem',
#   'in',
#   'India',
#   'with',
#   'the',
#   'program',
#   'will',
#   'set',
#   'up',
#   'the',
#   'core',
#   'AI',
#   'infrastructure',
#   'and',
#   'but',
#   'that',
#   'could',
#   'be',
#   'because',
#   'the',
#   'US',
#   'surveillance',
#   'system',
#   'guards',
#   'photo',
#   'of',
#   'Jordan',
#   'and',
#   'an',
#   'opposing',
#   'player',
#   'were',
#   'also',
#   'pardoned',
#   'after',
#   'established',
#   'IoT',
#   'Hub',
#   'for',
#   'the',
#   'selected',
#   'campuses',
#   'signal',
#   'the',
#   'end',
#   'of',
#   'the',
#   'holiday',
#   'travel',
#   'rush',
#   'Airlines',
#   'will',
#   'be',
#   'required',
#   'infrastructure',
#   'and',
#   'federal',
#   'loans',
#   'for',
#   'small',
#   'businesses',
#   "won't",
#   'IoT',
#   'Hub',
#   'for',
#   'the',
#   'selected',
#   'campuses',
#   'students',
#   'access',
#   'to',
#   'cloud',
#   'and',
#   'AI',
#   'services',
#   'As',
#   'part',
#   'of',
#   'the',
#   'program',
#   'the',
#   'Redmond',
#   'giant',
#   'which',
#   'wants',
#   'to',
#   'expand',
#   'its',
#   'reach',
#   'and',
#   'is',
#   'planning',
#   'to',
#   'build',
#   'a',
#   'strong',
#   'developer',
#   'ecosystem',
#   'in',
#   'India',
#   'with',
#   'the',
#   'program',
#   'will',
#   'set',
#   'up',
#   'the',
#   'core',
#   'AI',
#   'but',
#   'that',
#   'could',
#   'be',
#   'because',
#   'the',
#   'US',
#   'surveillance',
#   'system'],
#  ['Nearly',
#   '1',
#   '2',
#   'million',
#   'people',
#   'were',
#   'screened',
#   'at',
#   'airports',
#   'on',
#   'Wednesday',
#   'alone',
#   'an',
#   'air',
#   'travel',
#   'record',
#   'for',
#   'the',
#   'pandemic',
#   'While',
#   'the',
#   'number',
#   'of',
#   'travelers',
#   'screened',
#   'on',
#   'Christmas',
#   'Day',
#   '616',
#   '469',
#   'people',
#   'represents',
#   'just',
#   '23',
#   'of',
#   'the',
#   'total',
#   'screened',
#   'on',
#   'the',
#   'same',
#   'day',
#   'a',
#   'year',
#   'ago',
#   'the',
#   'figure',
#   'remains',
#   'worrying',
#   'for',
#   'officials',
#   'because',
#   'it',
#   "doesn't",
#   'signal',
#   'the',
#   'end',
#   'of',
#   'the',
#   'holiday',
#   'travel',
#   'rush',
#   'but',
#   'a',
#   'lull',
#   'before',
#   'travelers',
#   'begin',
#   'to',
#   'return',
#   'home',
#   'The',
#   'CDC',
#   'announced',
#   'Thursday',
#   'passengers',
#   'will',
#   'need',
#   'a',
#   'negative',
#   'PCR',
#   'or',
#   'antigen',
#   'test',
#   'within',
#   '72',
#   'hours',
#   'of',
#   'boarding',
#   'a',
#   'flight',
#   'from',
#   'the',
#   'UK',
#   'to',
#   'the',
#   'US',
#   'along',
#   'with',
#   'documentation',
#   'of',
#   'their',
#   'laboratory',
#   'results',
#   'Airlines',
#   'will',
#   'be',
#   'required',
#   'to',
#   'confirm',
#   'the',
#   'test',
#   'prior',
#   'to',
#   'the',
#   'flight',
#   'The',
#   'CDC',
#   'said',
#   'earlier',
#   'this',
#   'week',
#   'that',
#   'the',
#   'variant',
#   'has',
#   'not',
#   'been',
#   'identified',
#   'through',
#   'sequencing',
#   'efforts',
#   'in',
#   'the',
#   'US',
#   'but',
#   'that',
#   'could',
#   'be',
#   'because',
#   'the',
#   'US',
#   'surveillance',
#   'number',
#   'of',
#   'felonies',
#   'including',
#   'fraud',
#   'and',
#   'money',
#   'laundering',
#   'system',
#   'established',
#   'for',
#   'Covid',
#   '19',
#   "hasn't",
#   'caught',
#   'it',
#   'yet',
#   'infrastructure',
#   'and',
#   'IoT',
#   'Hub',
#   'for',
#   'the',
#   'selected',
#   'campuses',
#   'jobs',
#   'of',
#   'tomorrow',
#   'will',
#   'require',
#   'later',
#   'circulated',
#   'among',
#   'representing',
#   'the',
#   'probability',
#   'some',
#   'students',
#   'access',
#   'to',
#   'cloud',
#   'and',
#   'AI',
#   'services',
#   'As',
#   'part',
#   'challenge',
#   'the',
#   'election',
#   'results',
#   'of',
#   'the',
#   'program',
#   'the',
#   'Redmond',
#   'giant',
#   'which',
#   'wants',
#   'to',
#   'expand',
#   'its',
#   'reach',
#   'and',
#   'is',
#   'planning',
#   'guards',
#   'were',
#   'also',
#   'pardoned',
#   'after',
#   'to',
#   'build',
#   'a',
#   'strong',
#   'developer',
#   'onto',
#   'power',
#   'looked',
#   'increasingly',
#   'ecosystem',
#   'in',
#   'India',
#   'with',
#   'the',
#   'program',
#   'will',
#   'set',
#   'up',
#   'the',
#   'core',
#   'AI',
#   'but',
#   'that',
#   'could',
#   'be',
#   'because',
#   'the',
#   'US',
#   'surveillance',
#   'system'],
#  ['Jordan',
#   'was',
#   'named',
#   'the',
#   'Pac',
#   '12',
#   'Conference',
#   'Offensive',
#   'Freshman',
#   'Player',
#   'of',
#   'the',
#   'Year',
#   'last',
#   'week',
#   'The',
#   'native',
#   'of',
#   'Mesquite',
#   'Texas',
#   'rushed',
#   'for',
#   '597',
#   'yards',
#   'and',
#   'scored',
#   'six',
#   'rushing',
#   'touchdowns',
#   'in',
#   'a',
#   'shortened',
#   'five',
#   'game',
#   'season',
#   'for',
#   'the',
#   'Utah',
#   'Utes',
#   'Head',
#   'coach',
#   'Kyle',
#   'Whittingham',
#   'expressed',
#   'the',
#   "team's",
#   'deep',
#   'remorse',
#   'in',
#   'a',
#   'statement',
#   'Saturday',
#   'Last',
#   'year',
#   'a',
#   'photo',
#   'of',
#   'Jordan',
#   'and',
#   'an',
#   'opposing',
#   'player',
#   'went',
#   'viral',
#   'showing',
#   'the',
#   'two',
#   'kneeling',
#   'and',
#   'praying',
#   'after',
#   'a',
#   'high',
#   'school',
#   'football',
#   'game',
#   "Jordan's",
#   'aunt',
#   'took',
#   'a',
#   'photo',
#   'of',
#   'the',
#   'moment',
#   'in',
#   'appreciation',
#   'of',
#   'the',
#   'gesture',
#   'according',
#   'to',
#   'KXII',
#   'which',
#   'was',
#   'widely',
#   'shared',
#   'on',
#   'social',
#   'media',
#   'With',
#   'the',
#   'relief',
#   'package',
#   'left',
#   'unsigned',
#   'by',
#   'the',
#   'President',
#   'expanded',
#   'jobless',
#   'benefits',
#   'will',
#   'run',
#   'out',
#   'Saturday',
#   'government',
#   'funding',
#   'will',
#   'lapse',
#   'on',
#   'Monday',
#   'a',
#   'moratorium',
#   'on',
#   'evictions',
#   'will',
#   'expire',
#   'next',
#   'week',
#   'federal',
#   'loans',
#   'for',
#   'small',
#   'businesses',
#   "won't",
#   'be',
#   'revived',
#   'and',
#   'direct',
#   '600',
#   'payments',
#   'to',
#   'certain',
#   'Americans',
#   'will',
#   'be',
#   'delayed'],
#  ['Trump',
#   'also',
#   'offered',
#   'presidential',
#   'relief',
#   'to',
#   'corrupt',
#   'Republican',
#   'Congressmen',
#   'Duncan',
#   'Hunter',
#   'who',
#   'pleaded',
#   'guilty',
#   'to',
#   'a',
#   'charge',
#   'of',
#   'conspiracy',
#   'to',
#   'misuse',
#   'campaign',
#   'funds',
#   'Steve',
#   'Stockman',
#   'who',
#   'was',
#   'convicted',
#   'of',
#   'a',
#   'number',
#   'of',
#   'felonies',
#   'including',
#   'fraud',
#   'and',
#   'money',
#   'laundering',
#   'and',
#   'Chris',
#   'Collins',
#   'who',
#   'was',
#   'serving',
#   'time',
#   'on',
#   'charges',
#   'of',
#   'conspiracy',
#   'to',
#   'commit',
#   'securities',
#   'fraud',
#   'and',
#   'making',
#   'a',
#   'false',
#   'statement',
#   'along',
#   'with',
#   'Charles',
#   'Kushner',
#   'the',
#   'father',
#   'of',
#   'son',
#   'in',
#   'law',
#   'Jared',
#   'Kushner',
#   'who',
#   'was',
#   'sentenced',
#   'to',
#   'two',
#   'years',
#   'in',
#   'federal',
#   'prison',
#   'for',
#   'retaliating',
#   'against',
#   'a',
#   'federal',
#   'witness',
#   'evading',
#   'taxes',
#   'and',
#   'lying',
#   'to',
#   'the',
#   'Federal',
#   'Election',
#   'Commission',
#   'Four',
#   'Blackwater',
#   'guards',
#   'were',
#   'also',
#   'pardoned',
#   'after',
#   'a',
#   'lengthy',
#   'trial',
#   'found',
#   'them',
#   'guilty',
#   'of',
#   'killing',
#   '14',
#   'Iraqis',
#   'in',
#   '2007',
#   'The',
#   'list',
#   'goes',
#   'on',
#   'and',
#   'on',
#   'and',
#   'is',
#   'sure',
#   'to',
#   'grow',
#   'in',
#   'the',
#   'coming',
#   'weeks',
#   'While',
#   'Trump',
#   'is',
#   'certainly',
#   'not',
#   'the',
#   'first',
#   'to',
#   'use',
#   'his',
#   'presidential',
#   'powers',
#   'in',
#   'terrible',
#   'ways',
#   'the',
#   'scale',
#   'and',
#   'scope',
#   'of',
#   'his',
#   'decisions',
#   'many',
#   'of',
#   'which',
#   'are',
#   'unjustifiable',
#   'moves',
#   'him',
#   'to',
#   'the',
#   'very',
#   'top',
#   'of',
#   'the',
#   'list'],
#  ['it',
#   'turns',
#   'out',
#   'however',
#   'that',
#   'even',
#   'two',
#   'months',
#   'is',
#   'no',
#   'guarantee',
#   'of',
#   'a',
#   'smooth',
#   'interregnum',
#   'President',
#   'Donald',
#   'Trump',
#   'has',
#   'managed',
#   'to',
#   'use',
#   'his',
#   'remaining',
#   'time',
#   'in',
#   'office',
#   'to',
#   'act',
#   'as',
#   'a',
#   'political',
#   'wrecking',
#   'ball',
#   'while',
#   'the',
#   'country',
#   'is',
#   'still',
#   'being',
#   'ravaged',
#   'by',
#   'the',
#   'Covid',
#   '19',
#   'pandemic',
#   'Trump',
#   'who',
#   'had',
#   'been',
#   'spouting',
#   'false',
#   'claims',
#   'of',
#   'voter',
#   'fraud',
#   'for',
#   'months',
#   'launched',
#   'several',
#   'failed',
#   'lawsuits',
#   'in',
#   'an',
#   'attempt',
#   'to',
#   'challenge',
#   'the',
#   'election',
#   'results',
#   'in',
#   'key',
#   'swing',
#   'states',
#   'and',
#   'also',
#   'contacted',
#   'state',
#   'legislatures',
#   'to',
#   'try',
#   'to',
#   'persuade',
#   'them',
#   'to',
#   'intervene',
#   'on',
#   'his',
#   'behalf',
#   'Even',
#   'when',
#   'this',
#   'strategy',
#   'proved',
#   'unfruitful',
#   'and',
#   'his',
#   'attempt',
#   'to',
#   'hold',
#   'onto',
#   'power',
#   'looked',
#   'increasingly',
#   'desperate',
#   'the',
#   'President',
#   'continued',
#   'to',
#   'maintain',
#   'with',
#   'no',
#   'credible',
#   'evidence',
#   'that',
#   'the',
#   'election',
#   'had',
#   'been',
#   'rigged'],
#  ['Search',
#   'engines',
#   'presently',
#   'use',
#   'various',
#   'techniques',
#   'that',
#   'attempt',
#   'to',
#   'present',
#   'more',
#   'relevant',
#   'documents',
#   'Typically',
#   'documents',
#   'are',
#   'ranked',
#   'according',
#   'to',
#   'variations',
#   'of',
#   'a',
#   'standard',
#   'vector',
#   'space',
#   'model',
#   'These',
#   'variations',
#   'could',
#   'include',
#   'a',
#   'how',
#   'recently',
#   'the',
#   'document',
#   'was',
#   'updated',
#   'and',
#   'or',
#   'b',
#   'how',
#   'close',
#   'the',
#   'search',
#   'terms',
#   'are',
#   'to',
#   'the',
#   'beginning',
#   'of',
#   'the',
#   'document',
#   'Although',
#   'this',
#   'strategy',
#   'provides',
#   'search',
#   'results',
#   'that',
#   'are',
#   'better',
#   'than',
#   'with',
#   'no',
#   'ranking',
#   'at',
#   'all',
#   'the',
#   'results',
#   'still',
#   'have',
#   'relatively',
#   'low',
#   'quality',
#   'Moreover',
#   'when',
#   'searching',
#   'the',
#   'highly',
#   'competitive',
#   'web',
#   'this',
#   'measure',
#   'of',
#   'relevancy',
#   'is',
#   'vulnerable',
#   'to',
#   'spamming',
#   'techniques',
#   'that',
#   'authors',
#   'can',
#   'use',
#   'to',
#   'artificially',
#   'inflate',
#   'their',
#   "document's",
#   'relevance',
#   'in',
#   'order',
#   'to',
#   'draw',
#   'attention',
#   'to',
#   'it',
#   'or',
#   'its',
#   'advertisements',
#   'For',
#   'this',
#   'reason',
#   'search',
#   'results',
#   'often',
#   'contain',
#   'commercial',
#   'appeals',
#   'that',
#   'should',
#   'not',
#   'be',
#   'considered',
#   'a',
#   'match',
#   'to',
#   'the',
#   'query',
#   'Although',
#   'search',
#   'engines',
#   'are',
#   'designed',
#   'to',
#   'avoid',
#   'such',
#   'ruses',
#   'poorly',
#   'conceived',
#   'mechanisms',
#   'can',
#   'result',
#   'in',
#   'disappointing',
#   'failures',
#   'to',
#   'retrieve',
#   'desired',
#   'information'],
#  ['Due',
#   'to',
#   'the',
#   'developments',
#   'in',
#   'computer',
#   'technology',
#   'and',
#   'its',
#   'increase',
#   'in',
#   'popularity',
#   'large',
#   'numbers',
#   'of',
#   'people',
#   'have',
#   'recently',
#   'started',
#   'to',
#   'frequently',
#   'search',
#   'huge',
#   'databases',
#   'For',
#   'example',
#   'internet',
#   'search',
#   'engines',
#   'are',
#   'frequently',
#   'used',
#   'to',
#   'search',
#   'the',
#   'entire',
#   'world',
#   'wide',
#   'web',
#   'Currently',
#   'a',
#   'popular',
#   'search',
#   'engine',
#   'might',
#   'execute',
#   'over',
#   '30',
#   'million',
#   'searches',
#   'per',
#   'day',
#   'of',
#   'the',
#   'indexable',
#   'part',
#   'of',
#   'the',
#   'web',
#   'which',
#   'has',
#   'a',
#   'size',
#   'in',
#   'excess',
#   'of',
#   '500',
#   'Gigabytes',
#   'Information',
#   'retrieval',
#   'systems',
#   'are',
#   'traditionally',
#   'judged',
#   'by',
#   'their',
#   'precision',
#   'and',
#   'recall',
#   'What',
#   'is',
#   'often',
#   'neglected',
#   'however',
#   'is',
#   'the',
#   'quality',
#   'of',
#   'the',
#   'results',
#   'produced',
#   'by',
#   'these',
#   'search',
#   'engines',
#   'Large',
#   'databases',
#   'of',
#   'documents',
#   'such',
#   'as',
#   'the',
#   'web',
#   'contain',
#   'many',
#   'low',
#   'quality',
#   'documents',
#   'As',
#   'a',
#   'result',
#   'searches',
#   'typically',
#   'return',
#   'hundreds',
#   'of',
#   'irrelevant',
#   'or',
#   'unwanted',
#   'documents',
#   'which',
#   'camouflage',
#   'the',
#   'few',
#   'relevant',
#   'ones',
#   'In',
#   'order',
#   'to',
#   'improve',
#   'the',
#   'selectivity',
#   'of',
#   'the',
#   'results',
#   'common',
#   'techniques',
#   'allow',
#   'the',
#   'user',
#   'to',
#   'constrain',
#   'the',
#   'scope',
#   'of',
#   'the',
#   'search',
#   'to',
#   'a',
#   'specified',
#   'subset',
#   'of',
#   'the',
#   'database',
#   'or',
#   'to',
#   'provide',
#   'additional',
#   'search',
#   'terms',
#   'These',
#   'techniques',
#   'are',
#   'most',
#   'effective',
#   'in',
#   'cases',
#   'where',
#   'the',
#   'database',
#   'is',
#   'homogeneous',
#   'and',
#   'already',
#   'classified',
#   'into',
#   'subsets',
#   'or',
#   'in',
#   'cases',
#   'where',
#   'the',
#   'user',
#   'is',
#   'searching',
#   'for',
#   'well',
#   'known',
#   'and',
#   'specific',
#   'information',
#   'In',
#   'other',
#   'cases',
#   'however',
#   'these',
#   'techniques',
#   'are',
#   'often',
#   'not',
#   'effective',
#   'because',
#   'each',
#   'constraint',
#   'introduced',
#   'by',
#   'the',
#   'user',
#   'increases',
#   'the',
#   'chances',
#   'that',
#   'the',
#   'desired',
#   'information',
#   'will',
#   'be',
#   'inadvertently',
#   'eliminated',
#   'from',
#   'the',
#   'search',
#   'results'],
#  ['Ms',
#   'Groves',
#   'had',
#   'originally',
#   'sent',
#   'the',
#   'video',
#   'in',
#   'which',
#   'she',
#   'looked',
#   'into',
#   'the',
#   'camera',
#   'and',
#   'said',
#   'I',
#   'can',
#   'drive',
#   'followed',
#   'by',
#   'the',
#   'slur',
#   'to',
#   'a',
#   'friend',
#   'on',
#   'Snapchat',
#   'in',
#   '2016',
#   'when',
#   'she',
#   'was',
#   'a',
#   'freshman',
#   'and',
#   'had',
#   'just',
#   'gotten',
#   'her',
#   "learner's",
#   'permit',
#   'It',
#   'later',
#   'circulated',
#   'among',
#   'some',
#   'students',
#   'at',
#   'Heritage',
#   'High',
#   'School',
#   'which',
#   'she',
#   'and',
#   'Mr',
#   'Galligan',
#   'attended',
#   'but',
#   'did',
#   'not',
#   'cause',
#   'much',
#   'of',
#   'a',
#   'stir',
#   'Mr',
#   'Galligan',
#   'had',
#   'not',
#   'seen',
#   'the',
#   'video',
#   'before',
#   'receiving',
#   'it',
#   'last',
#   'school',
#   'year',
#   'when',
#   'he',
#   'and',
#   'Ms',
#   'Groves',
#   'were',
#   'seniors',
#   'By',
#   'then',
#   'she',
#   'was',
#   'a',
#   'varsity',
#   'cheer',
#   'captain',
#   'who',
#   'dreamed',
#   'of',
#   'attending',
#   'the',
#   'University',
#   'of',
#   'Tennessee',
#   'Knoxville',
#   'whose',
#   'cheer',
#   'team',
#   'was',
#   'the',
#   'reigning',
#   'national',
#   'champion',
#   'When',
#   'she',
#   'made',
#   'the',
#   'team',
#   'in',
#   'May',
#   'her',
#   'parents',
#   'celebrated',
#   'with',
#   'a',
#   'cake',
#   'and',
#   'orange',
#   'balloons',
#   'the',
#   "university's",
#   'official',
#   'color',
#   'The',
#   'next',
#   'month',
#   'as',
#   'protests',
#   'were',
#   'sweeping',
#   'the',
#   'nation',
#   'after',
#   'the',
#   'police',
#   'killing',
#   'of',
#   'George',
#   'Floyd',
#   'Ms',
#   'Groves',
#   'in',
#   'a',
#   'public',
#   'Instagram',
#   'post',
#   'urged',
#   'people',
#   'to',
#   'protest',
#   'donate',
#   'sign',
#   'a',
#   'petition',
#   'rally',
#   'do',
#   'something',
#   'in',
#   'support',
#   'of',
#   'the',
#   'Black',
#   'Lives',
#   'Matter',
#   'movement',
#   'access',
#   'to',
#   'cloud',
#   'and',
#   'AI',
#   'services',
#   'As',
#   'part',
#   'of',
#   'the',
#   'program',
#   'the',
#   'Redmond',
#   'giant',
#   'which',
#   'wants',
#   'to',
#   'expand',
#   'its',
#   'reach',
#   'and',
#   'is',
#   'planning',
#   'to',
#   'build',
#   'a',
#   'strong',
#   'developer',
#   'ecosystem',
#   'in',
#   'India',
#   'with',
#   'the',
#   'program',
#   'will',
#   'set',
#   'up',
#   'the',
#   'core',
#   'AI',
#   'infrastructure',
#   'and',
#   'IoT',
#   'Hub',
#   'for',
#   'the',
#   'selected',
#   'campuses',
#   'The',
#   'company',
#   'will',
#   'provide',
#   'AI',
#   'development',
#   'tools',
#   'and',
#   'Azure',
#   'AI',
#   'services',
#   'such',
#   'as',
#   'Microsoft',
#   'Cognitive',
#   'Services',
#   'Bot',
#   'Services',
#   'and',
#   'Azure',
#   'Machine',
#   'Learning',
#   'According',
#   'to',
#   'Manish',
#   'Prakash',
#   'Country',
#   'General',
#   'Manager',
#   'PS',
#   'Health',
#   'and',
#   'Education',
#   'Microsoft',
#   'India',
#   'said',
#   'With',
#   'AI',
#   'being',
#   'the',
#   'defining',
#   'technology',
#   'of',
#   'our',
#   'time',
#   'it',
#   'is',
#   'transforming',
#   'lives',
#   'and',
#   'industry',
#   'and',
#   'the',
#   'jobs',
#   'of',
#   'tomorrow',
#   'will',
#   'require',
#   'a',
#   'different',
#   'skillset',
#   'This',
#   'will',
#   'require',
#   'more',
#   'collaborations',
#   'and',
#   'training',
#   'and',
#   'working',
#   'with',
#   'AI']]

# %% [markdown]
# <a id='stop_word_removal'></a>
# > ### Stop Word Removal

# %%
from nltk.corpus import stopwords 
stopwords_english = stopwords.words('english')

# %%
Cleaned_tokenized_documentList = []
for document in tokenized_documentList:
    cleandoc = []
    for word in document:
        if word.lower() not in stopwords_english:
            cleandoc.append(word)
    Cleaned_tokenized_documentList.append(cleandoc)

# %%
Cleaned_tokenized_documentList
# Out:
# [['Perdue',
#   'campaign',
#   'respond',
#   "CNN's",
#   'inquiries',
#   'status',
#   'ad',
#   'Saturday',
#   'ignored',
#   'questions',
#   'senator',
#   'stands',
#   "Trump's",
#   'calls',
#   'changes',
#   'bill',
#   'news',
#   'conference',
#   'Wednesday',
#   'Loeffler',
#   'said',
#   'would',
#   'open',
#   'idea',
#   'bigger',
#   'checks',
#   'argued',
#   'parts',
#   'package',
#   'would',
#   'cut',
#   'order',
#   'accommodate',
#   'expense',
#   "Trump's",
#   'mixed',
#   'signals',
#   'relief',
#   'bill',
#   'one',
#   'example',
#   'erratic',
#   'behavior',
#   'waning',
#   'days',
#   'presidency',
#   'interrupting',
#   'careful',
#   'messaging',
#   'Republicans',
#   'trying',
#   'craft',
#   'fight',
#   'hold',
#   'onto',
#   'two',
#   'seats',
#   'retain',
#   'control',
#   'majority',
#   'US',
#   'Senate',
#   'Trump',
#   'last',
#   'week',
#   'vetoed',
#   'National',
#   'Defense',
#   'Authorization',
#   'Act',
#   'legislation',
#   'Loeffler',
#   'Perdue',
#   'supported',
#   'setting',
#   'first',
#   'possible',
#   'veto',
#   'override',
#   'presidency',
#   'Trump',
#   'also',
#   'continues',
#   'undermine',
#   'voting',
#   'system',
#   'Georgia',
#   'relentlessly',
#   'attack',
#   'Republican',
#   'leaders',
#   'administered',
#   'November',
#   'election',
#   'state',
#   'lost',
#   'President',
#   'elect',
#   'Joe',
#   'Biden',
#   'rhetoric',
#   'left',
#   'GOP',
#   'difficult',
#   'spot',
#   'begging',
#   'supporters',
#   'come',
#   'vote',
#   'two',
#   'runoffs',
#   'January',
#   '5',
#   'time',
#   'entertaining',
#   'baseless',
#   'claims',
#   'voting',
#   'system',
#   'rife',
#   'fraud'],
#  ['attempt',
#   'build',
#   'AI',
#   'ready',
#   'workforce',
#   'Microsoft',
#   'announced',
#   'Intelligent',
#   'Cloud',
#   'Hub',
#   'launched',
#   'empower',
#   'next',
#   'generation',
#   'students',
#   'AI',
#   'ready',
#   'skills',
#   'Envisioned',
#   'three',
#   'year',
#   'collaborative',
#   'program',
#   'Intelligent',
#   'Cloud',
#   'Hub',
#   'support',
#   'around',
#   '100',
#   'institutions',
#   'AI',
#   'infrastructure',
#   'course',
#   'content',
#   'curriculum',
#   'developer',
#   'support',
#   'development',
#   'tools',
#   'give',
#   'students',
#   'access',
#   'cloud',
#   'AI',
#   'services',
#   'part',
#   'program',
#   'Redmond',
#   'giant',
#   'wants',
#   'expand',
#   'reach',
#   'planning',
#   'build',
#   'strong',
#   'developer',
#   'ecosystem',
#   'India',
#   'program',
#   'set',
#   'core',
#   'AI',
#   'could',
#   'US',
#   'surveillance',
#   'system',
#   'established',
#   'infrastructure',
#   'IoT',
#   'Hub',
#   'selected',
#   'campuses',
#   'company',
#   'provide',
#   'AI',
#   'development',
#   'tools',
#   'Azure',
#   'AI',
#   'services',
#   'photo',
#   'Jordan',
#   'opposing',
#   'player',
#   'Microsoft',
#   'Cognitive',
#   'Services',
#   'Bot',
#   'Services',
#   'Azure',
#   'Machine',
#   'Learning',
#   'According',
#   'Manish',
#   'Prakash',
#   'Country',
#   'General',
#   'Manager',
#   'PS',
#   'Health',
#   'Education',
#   'Microsoft',
#   'India',
#   'said',
#   'AI',
#   'defining',
#   'technology',
#   'time',
#   'transforming',
#   'lives',
#   'industry',
#   'jobs',
#   'tomorrow',
#   'require',
#   'different',
#   'skillset',
#   'require',
#   'collaborations',
#   'federal',
#   'loans',
#   'small',
#   'businesses',
#   'training',
#   'working',
#   'AI',
#   "That's",
#   'become',
#   'critical',
#   'ever',
#   'educational',
#   'institutions',
#   'integrate',
#   'new',
#   'cloud',
#   'AI',
#   'technologies',
#   'program',
#   'attempt',
#   'challenge',
#   'election',
#   'results',
#   'ramp',
#   'institutional',
#   'set',
#   'build',
#   'capabilities',
#   'among',
#   'educators',
#   'educate',
#   'workforce',
#   'tomorrow',
#   'program',
#   'aims',
#   'build',
#   'cognitive',
#   'skills',
#   'onto',
#   'power',
#   'looked',
#   'increasingly',
#   'depth',
#   'understanding',
#   'developing',
#   'intelligent',
#   'cloud',
#   'connected',
#   'solutions',
#   'applications',
#   'across',
#   'industry',
#   'Earlier',
#   'April',
#   'year',
#   'company',
#   'announced',
#   'Microsoft',
#   'Professional',
#   'Program',
#   'AI',
#   'learning',
#   'track',
#   'open',
#   'public',
#   'program',
#   'developed',
#   'provide',
#   'job',
#   'ready',
#   'skills',
#   'programmers',
#   'wanted',
#   'hone',
#   'skills',
#   'AI',
#   'data',
#   'science',
#   'series',
#   'online',
#   'courses',
#   'featured',
#   'hands',
#   'labs',
#   'expert',
#   'instructors',
#   'well',
#   'program',
#   'also',
#   'included',
#   'developer',
#   'focused',
#   'AI',
#   'school',
#   'provided',
#   'bunch',
#   'assets',
#   'help',
#   'build',
#   'AI',
#   'skills',
#   'next',
#   'month'],
#  ['method',
#   'assigns',
#   'importance',
#   'ranks',
#   'nodes',
#   'linked',
#   'database',
#   'database',
#   'documents',
#   'containing',
#   'citations',
#   'world',
#   'wide',
#   'web',
#   'hypermedia',
#   'database',
#   'rank',
#   'assigned',
#   'document',
#   'calculated',
#   'ranks',
#   'documents',
#   'citing',
#   'addition',
#   'rank',
#   'document',
#   'calculated',
#   'constant',
#   'representing',
#   'probability',
#   'browser',
#   'database',
#   'randomly',
#   'jump',
#   'document',
#   'method',
#   'particularly',
#   'useful',
#   'enhancing',
#   'performance',
#   'search',
#   'engine',
#   'results',
#   'hypermedia',
#   'databases',
#   'number',
#   'felonies',
#   'including',
#   'fraud',
#   'money',
#   'laundering',
#   'world',
#   'wide',
#   'web',
#   'whose',
#   'documents',
#   'large',
#   'variation',
#   'quality',
#   'planning',
#   'build',
#   'strong',
#   'developer',
#   'ecosystem',
#   'India',
#   'program',
#   'set',
#   'core',
#   'AI',
#   'infrastructure',
#   'could',
#   'US',
#   'surveillance',
#   'system',
#   'guards',
#   'photo',
#   'Jordan',
#   'opposing',
#   'player',
#   'also',
#   'pardoned',
#   'established',
#   'IoT',
#   'Hub',
#   'selected',
#   'campuses',
#   'signal',
#   'end',
#   'holiday',
#   'travel',
#   'rush',
#   'Airlines',
#   'required',
#   'infrastructure',
#   'federal',
#   'loans',
#   'small',
#   'businesses',
#   'IoT',
#   'Hub',
#   'selected',
#   'campuses',
#   'students',
#   'access',
#   'cloud',
#   'AI',
#   'services',
#   'part',
#   'program',
#   'Redmond',
#   'giant',
#   'wants',
#   'expand',
#   'reach',
#   'planning',
#   'build',
#   'strong',
#   'developer',
#   'ecosystem',
#   'India',
#   'program',
#   'set',
#   'core',
#   'AI',
#   'could',
#   'US',
#   'surveillance',
#   'system'],
#  ['Nearly',
#   '1',
#   '2',
#   'million',
#   'people',
#   'screened',
#   'airports',
#   'Wednesday',
#   'alone',
#   'air',
#   'travel',
#   'record',
#   'pandemic',
#   'number',
#   'travelers',
#   'screened',
#   'Christmas',
#   'Day',
#   '616',
#   '469',
#   'people',
#   'represents',
#   '23',
#   'total',
#   'screened',
#   'day',
#   'year',
#   'ago',
#   'figure',
#   'remains',
#   'worrying',
#   'officials',
#   'signal',
#   'end',
#   'holiday',
#   'travel',
#   'rush',
#   'lull',
#   'travelers',
#   'begin',
#   'return',
#   'home',
#   'CDC',
#   'announced',
#   'Thursday',
#   'passengers',
#   'need',
#   'negative',
#   'PCR',
#   'antigen',
#   'test',
#   'within',
#   '72',
#   'hours',
#   'boarding',
#   'flight',
#   'UK',
#   'US',
#   'along',
#   'documentation',
#   'laboratory',
#   'results',
#   'Airlines',
#   'required',
#   'confirm',
#   'test',
#   'prior',
#   'flight',
#   'CDC',
#   'said',
#   'earlier',
#   'week',
#   'variant',
#   'identified',
#   'sequencing',
#   'efforts',
#   'US',
#   'could',
#   'US',
#   'surveillance',
#   'number',
#   'felonies',
#   'including',
#   'fraud',
#   'money',
#   'laundering',
#   'system',
#   'established',
#   'Covid',
#   '19',
#   'caught',
#   'yet',
#   'infrastructure',
#   'IoT',
#   'Hub',
#   'selected',
#   'campuses',
#   'jobs',
#   'tomorrow',
#   'require',
#   'later',
#   'circulated',
#   'among',
#   'representing',
#   'probability',
#   'students',
#   'access',
#   'cloud',
#   'AI',
#   'services',
#   'part',
#   'challenge',
#   'election',
#   'results',
#   'program',
#   'Redmond',
#   'giant',
#   'wants',
#   'expand',
#   'reach',
#   'planning',
#   'guards',
#   'also',
#   'pardoned',
#   'build',
#   'strong',
#   'developer',
#   'onto',
#   'power',
#   'looked',
#   'increasingly',
#   'ecosystem',
#   'India',
#   'program',
#   'set',
#   'core',
#   'AI',
#   'could',
#   'US',
#   'surveillance',
#   'system'],
#  ['Jordan',
#   'named',
#   'Pac',
#   '12',
#   'Conference',
#   'Offensive',
#   'Freshman',
#   'Player',
#   'Year',
#   'last',
#   'week',
#   'native',
#   'Mesquite',
#   'Texas',
#   'rushed',
#   '597',
#   'yards',
#   'scored',
#   'six',
#   'rushing',
#   'touchdowns',
#   'shortened',
#   'five',
#   'game',
#   'season',
#   'Utah',
#   'Utes',
#   'Head',
#   'coach',
#   'Kyle',
#   'Whittingham',
#   'expressed',
#   "team's",
#   'deep',
#   'remorse',
#   'statement',
#   'Saturday',
#   'Last',
#   'year',
#   'photo',
#   'Jordan',
#   'opposing',
#   'player',
#   'went',
#   'viral',
#   'showing',
#   'two',
#   'kneeling',
#   'praying',
#   'high',
#   'school',
#   'football',
#   'game',
#   "Jordan's",
#   'aunt',
#   'took',
#   'photo',
#   'moment',
#   'appreciation',
#   'gesture',
#   'according',
#   'KXII',
#   'widely',
#   'shared',
#   'social',
#   'media',
#   'relief',
#   'package',
#   'left',
#   'unsigned',
#   'President',
#   'expanded',
#   'jobless',
#   'benefits',
#   'run',
#   'Saturday',
#   'government',
#   'funding',
#   'lapse',
#   'Monday',
#   'moratorium',
#   'evictions',
#   'expire',
#   'next',
#   'week',
#   'federal',
#   'loans',
#   'small',
#   'businesses',
#   'revived',
#   'direct',
#   '600',
#   'payments',
#   'certain',
#   'Americans',
#   'delayed'],
#  ['Trump',
#   'also',
#   'offered',
#   'presidential',
#   'relief',
#   'corrupt',
#   'Republican',
#   'Congressmen',
#   'Duncan',
#   'Hunter',
#   'pleaded',
#   'guilty',
#   'charge',
#   'conspiracy',
#   'misuse',
#   'campaign',
#   'funds',
#   'Steve',
#   'Stockman',
#   'convicted',
#   'number',
#   'felonies',
#   'including',
#   'fraud',
#   'money',
#   'laundering',
#   'Chris',
#   'Collins',
#   'serving',
#   'time',
#   'charges',
#   'conspiracy',
#   'commit',
#   'securities',
#   'fraud',
#   'making',
#   'false',
#   'statement',
#   'along',
#   'Charles',
#   'Kushner',
#   'father',
#   'son',
#   'law',
#   'Jared',
#   'Kushner',
#   'sentenced',
#   'two',
#   'years',
#   'federal',
#   'prison',
#   'retaliating',
#   'federal',
#   'witness',
#   'evading',
#   'taxes',
#   'lying',
#   'Federal',
#   'Election',
#   'Commission',
#   'Four',
#   'Blackwater',
#   'guards',
#   'also',
#   'pardoned',
#   'lengthy',
#   'trial',
#   'found',
#   'guilty',
#   'killing',
#   '14',
#   'Iraqis',
#   '2007',
#   'list',
#   'goes',
#   'sure',
#   'grow',
#   'coming',
#   'weeks',
#   'Trump',
#   'certainly',
#   'first',
#   'use',
#   'presidential',
#   'powers',
#   'terrible',
#   'ways',
#   'scale',
#   'scope',
#   'decisions',
#   'many',
#   'unjustifiable',
#   'moves',
#   'top',
#   'list'],
#  ['turns',
#   'however',
#   'even',
#   'two',
#   'months',
#   'guarantee',
#   'smooth',
#   'interregnum',
#   'President',
#   'Donald',
#   'Trump',
#   'managed',
#   'use',
#   'remaining',
#   'time',
#   'office',
#   'act',
#   'political',
#   'wrecking',
#   'ball',
#   'country',
#   'still',
#   'ravaged',
#   'Covid',
#   '19',
#   'pandemic',
#   'Trump',
#   'spouting',
#   'false',
#   'claims',
#   'voter',
#   'fraud',
#   'months',
#   'launched',
#   'several',
#   'failed',
#   'lawsuits',
#   'attempt',
#   'challenge',
#   'election',
#   'results',
#   'key',
#   'swing',
#   'states',
#   'also',
#   'contacted',
#   'state',
#   'legislatures',
#   'try',
#   'persuade',
#   'intervene',
#   'behalf',
#   'Even',
#   'strategy',
#   'proved',
#   'unfruitful',
#   'attempt',
#   'hold',
#   'onto',
#   'power',
#   'looked',
#   'increasingly',
#   'desperate',
#   'President',
#   'continued',
#   'maintain',
#   'credible',
#   'evidence',
#   'election',
#   'rigged'],
#  ['Search',
#   'engines',
#   'presently',
#   'use',
#   'various',
#   'techniques',
#   'attempt',
#   'present',
#   'relevant',
#   'documents',
#   'Typically',
#   'documents',
#   'ranked',
#   'according',
#   'variations',
#   'standard',
#   'vector',
#   'space',
#   'model',
#   'variations',
#   'could',
#   'include',
#   'recently',
#   'document',
#   'updated',
#   'b',
#   'close',
#   'search',
#   'terms',
#   'beginning',
#   'document',
#   'Although',
#   'strategy',
#   'provides',
#   'search',
#   'results',
#   'better',
#   'ranking',
#   'results',
#   'still',
#   'relatively',
#   'low',
#   'quality',
#   'Moreover',
#   'searching',
#   'highly',
#   'competitive',
#   'web',
#   'measure',
#   'relevancy',
#   'vulnerable',
#   'spamming',
#   'techniques',
#   'authors',
#   'use',
#   'artificially',
#   'inflate',
#   "document's",
#   'relevance',
#   'order',
#   'draw',
#   'attention',
#   'advertisements',
#   'reason',
#   'search',
#   'results',
#   'often',
#   'contain',
#   'commercial',
#   'appeals',
#   'considered',
#   'match',
#   'query',
#   'Although',
#   'search',
#   'engines',
#   'designed',
#   'avoid',
#   'ruses',
#   'poorly',
#   'conceived',
#   'mechanisms',
#   'result',
#   'disappointing',
#   'failures',
#   'retrieve',
#   'desired',
#   'information'],
#  ['Due',
#   'developments',
#   'computer',
#   'technology',
#   'increase',
#   'popularity',
#   'large',
#   'numbers',
#   'people',
#   'recently',
#   'started',
#   'frequently',
#   'search',
#   'huge',
#   'databases',
#   'example',
#   'internet',
#   'search',
#   'engines',
#   'frequently',
#   'used',
#   'search',
#   'entire',
#   'world',
#   'wide',
#   'web',
#   'Currently',
#   'popular',
#   'search',
#   'engine',
#   'might',
#   'execute',
#   '30',
#   'million',
#   'searches',
#   'per',
#   'day',
#   'indexable',
#   'part',
#   'web',
#   'size',
#   'excess',
#   '500',
#   'Gigabytes',
#   'Information',
#   'retrieval',
#   'systems',
#   'traditionally',
#   'judged',
#   'precision',
#   'recall',
#   'often',
#   'neglected',
#   'however',
#   'quality',
#   'results',
#   'produced',
#   'search',
#   'engines',
#   'Large',
#   'databases',
#   'documents',
#   'web',
#   'contain',
#   'many',
#   'low',
#   'quality',
#   'documents',
#   'result',
#   'searches',
#   'typically',
#   'return',
#   'hundreds',
#   'irrelevant',
#   'unwanted',
#   'documents',
#   'camouflage',
#   'relevant',
#   'ones',
#   'order',
#   'improve',
#   'selectivity',
#   'results',
#   'common',
#   'techniques',
#   'allow',
#   'user',
#   'constrain',
#   'scope',
#   'search',
#   'specified',
#   'subset',
#   'database',
#   'provide',
#   'additional',
#   'search',
#   'terms',
#   'techniques',
#   'effective',
#   'cases',
#   'database',
#   'homogeneous',
#   'already',
#   'classified',
#   'subsets',
#   'cases',
#   'user',
#   'searching',
#   'well',
#   'known',
#   'specific',
#   'information',
#   'cases',
#   'however',
#   'techniques',
#   'often',
#   'effective',
#   'constraint',
#   'introduced',
#   'user',
#   'increases',
#   'chances',
#   'desired',
#   'information',
#   'inadvertently',
#   'eliminated',
#   'search',
#   'results'],
#  ['Ms',
#   'Groves',
#   'originally',
#   'sent',
#   'video',
#   'looked',
#   'camera',
#   'said',
#   'drive',
#   'followed',
#   'slur',
#   'friend',
#   'Snapchat',
#   '2016',
#   'freshman',
#   'gotten',
#   "learner's",
#   'permit',
#   'later',
#   'circulated',
#   'among',
#   'students',
#   'Heritage',
#   'High',
#   'School',
#   'Mr',
#   'Galligan',
#   'attended',
#   'cause',
#   'much',
#   'stir',
#   'Mr',
#   'Galligan',
#   'seen',
#   'video',
#   'receiving',
#   'last',
#   'school',
#   'year',
#   'Ms',
#   'Groves',
#   'seniors',
#   'varsity',
#   'cheer',
#   'captain',
#   'dreamed',
#   'attending',
#   'University',
#   'Tennessee',
#   'Knoxville',
#   'whose',
#   'cheer',
#   'team',
#   'reigning',
#   'national',
#   'champion',
#   'made',
#   'team',
#   'May',
#   'parents',
#   'celebrated',
#   'cake',
#   'orange',
#   'balloons',
#   "university's",
#   'official',
#   'color',
#   'next',
#   'month',
#   'protests',
#   'sweeping',
#   'nation',
#   'police',
#   'killing',
#   'George',
#   'Floyd',
#   'Ms',
#   'Groves',
#   'public',
#   'Instagram',
#   'post',
#   'urged',
#   'people',
#   'protest',
#   'donate',
#   'sign',
#   'petition',
#   'rally',
#   'something',
#   'support',
#   'Black',
#   'Lives',
#   'Matter',
#   'movement',
#   'access',
#   'cloud',
#   'AI',
#   'services',
#   'part',
#   'program',
#   'Redmond',
#   'giant',
#   'wants',
#   'expand',
#   'reach',
#   'planning',
#   'build',
#   'strong',
#   'developer',
#   'ecosystem',
#   'India',
#   'program',
#   'set',
#   'core',
#   'AI',
#   'infrastructure',
#   'IoT',
#   'Hub',
#   'selected',
#   'campuses',
#   'company',
#   'provide',
#   'AI',
#   'development',
#   'tools',
#   'Azure',
#   'AI',
#   'services',
#   'Microsoft',
#   'Cognitive',
#   'Services',
#   'Bot',
#   'Services',
#   'Azure',
#   'Machine',
#   'Learning',
#   'According',
#   'Manish',
#   'Prakash',
#   'Country',
#   'General',
#   'Manager',
#   'PS',
#   'Health',
#   'Education',
#   'Microsoft',
#   'India',
#   'said',
#   'AI',
#   'defining',
#   'technology',
#   'time',
#   'transforming',
#   'lives',
#   'industry',
#   'jobs',
#   'tomorrow',
#   'require',
#   'different',
#   'skillset',
#   'require',
#   'collaborations',
#   'training',
#   'working',
#   'AI']]

# %% [markdown]
# <a id='positioal_index_model'></a>
# ## Positioal Index Model

# %% [markdown]
# <a id='constructing_auxiliary'></a>
# > ### Constructing Auxiliary Structure(s)

# %%
#Creat unique Words Per Document and Number of Word Per Document
uniqueWordsPerDoc = []
numWordPerDoc = []
totalWords = 0
for document in Cleaned_tokenized_documentList:
    num = len(document)
    totalWords += num
    numWordPerDoc.append(num)
    list_set  = set(document)
    uniqueWordsPerDoc += (list(list_set))

# %%
#Creat unique Words in all Documents
list_set  = set(uniqueWordsPerDoc)
uniqueWords = (list(list_set))

print("total number Of word is: ",totalWords)
print("Number of unique Words is: ",len(uniqueWords))
# Out:
# total number Of word is:  1253
# Number of unique Words is:  749

# %% [markdown]
# Create a List consist of  Posting  List and  Positional Index

# %%
words = {}
for word in uniqueWords:
    words[word] = {}
    docNum = 0
    for document in Cleaned_tokenized_documentList:
        if word in document:
            index_pos_list = [ i for i in range(len(document)) if document[i] == word ]
            words[word][docNum] = index_pos_list
        docNum += 1

# %%
words
# Out:
# {'remorse': {4: [34]},
#  'elect': {0: [97]},
#  'generation': {1: [13]},
#  'transforming': {1: [108], 9: [152]},
#  'use': {5: [82], 6: [12], 7: [3, 54]},
#  'convicted': {5: [19]},
#  'Education': {1: [100], 9: [144]},
#  'industry': {1: [110, 169], 9: [154]},
#  'dreamed': {9: [45]},
#  'fight': {0: [52]},
#  'return': {3: [40], 8: [71]},
#  'first': {0: [75], 5: [81]},
#  'standard': {7: [15]},
#  "team's": {4: [32]},
#  'browser': {2: [30]},
#  'highly': {7: [45]},
#  'technology': {1: [106], 8: [3], 9: [150]},
#  'guilty': {5: [11, 68]},
#  'Galligan': {9: [26, 32]},
#  'commercial': {7: [68]},
#  'depth': {1: [160]},
#  'Country': {1: [95], 9: [139]},
#  'ball': {6: [19]},
#  'provides': {7: [33]},
#  'ramp': {1: [141]},
#  'courses': {1: [198]},
#  'become': {1: [126]},
#  'across': {1: [168]},
#  'list': {5: [73, 94]},
#  'school': {1: [211], 4: [50], 9: [37]},
#  'certainly': {5: [80]},
#  'Prakash': {1: [94], 9: [138]},
#  'made': {9: [56]},
#  'pleaded': {5: [10]},
#  'year': {1: [20, 172], 3: [26], 4: [38], 9: [38]},
#  'desired': {7: [86], 8: [122]},
#  'Donald': {6: [9]},
#  'technologies': {1: [135]},
#  'Loeffler': {0: [19, 71]},
#  'coach': {4: [28]},
#  'Head': {4: [27]},
#  'terrible': {5: [85]},
#  'interrupting': {0: [46]},
#  'nodes': {2: [4]},
#  'Cognitive': {1: [85], 9: [129]},
#  'Day': {3: [17]},
#  'Congressmen': {5: [7]},
#  'charge': {5: [12]},
#  'along': {3: [58], 5: [38]},
#  'capabilities': {1: [145]},
#  'jobless': {4: [72]},
#  '100': {1: [28]},
#  'instructors': {1: [203]},
#  'inquiries': {0: [4]},
#  'neglected': {8: [52]},
#  'movement': {9: [93]},
#  'relentlessly': {0: [87]},
#  'found': {5: [67]},
#  'Program': {1: [177]},
#  'Knoxville': {9: [49]},
#  'terms': {7: [28], 8: [96]},
#  'wrecking': {6: [18]},
#  'frequently': {8: [11, 19]},
#  'engine': {2: [41], 8: [29]},
#  'contain': {7: [67], 8: [63]},
#  'Conference': {4: [4]},
#  'behalf': {6: [51]},
#  'scored': {4: [17]},
#  'President': {0: [96], 4: [70], 6: [8, 63]},
#  'trying': {0: [50]},
#  'evading': {5: [54]},
#  'assigned': {2: [17]},
#  'presently': {7: [2]},
#  'US': {0: [60], 1: [63], 2: [71, 125], 3: [57, 76, 78, 138]},
#  'series': {1: [196]},
#  'collaborative': {1: [21]},
#  'confirm': {3: [64]},
#  'spouting': {6: [27]},
#  'unfruitful': {6: [55]},
#  'retrieve': {7: [85]},
#  'National': {0: [66]},
#  'opposing': {1: [82], 2: [77], 4: [41]},
#  'started': {8: [10]},
#  'poorly': {7: [79]},
#  'native': {4: [11]},
#  'Search': {7: [0]},
#  'powers': {5: [84]},
#  'caught': {3: [90]},
#  'persuade': {6: [49]},
#  'Stockman': {5: [18]},
#  'moment': {4: [57]},
#  "university's": {9: [64]},
#  'years': {5: [48]},
#  'two': {0: [55, 109], 4: [46], 5: [47], 6: [3]},
#  'linked': {2: [5]},
#  'pardoned': {2: [80], 3: [123], 5: [64]},
#  'High': {9: [23]},
#  '1': {3: [1]},
#  '5': {0: [112]},
#  'provide': {1: [73, 185], 8: [93], 9: [121]},
#  'Microsoft': {1: [5, 84, 101, 175], 9: [128, 145]},
#  'ad': {0: [6]},
#  'federal': {1: [118], 2: [94], 4: [85], 5: [49, 52]},
#  'aims': {1: [152]},
#  'police': {9: [72]},
#  'attack': {0: [88]},
#  'Manager': {1: [97], 9: [141]},
#  'provided': {1: [212]},
#  '2016': {9: [13]},
#  'model': {7: [18]},
#  'Jared': {5: [44]},
#  "That's": {1: [125]},
#  'mixed': {0: [35]},
#  'guarantee': {6: [5]},
#  'match': {7: [71]},
#  'addition': {2: [23]},
#  'stands': {0: [11]},
#  'varsity': {9: [42]},
#  'part': {1: [45], 2: [107], 3: [110], 8: [38], 9: [98]},
#  'scale': {5: [87]},
#  'Utes': {4: [26]},
#  'office': {6: [15]},
#  'Large': {8: [59]},
#  'give': {1: [39]},
#  'ways': {5: [86]},
#  'Authorization': {0: [68]},
#  'Redmond': {1: [47], 2: [109], 3: [115], 9: [100]},
#  'bunch': {1: [213]},
#  'could': {1: [62], 2: [70, 124], 3: [77, 137], 7: [20]},
#  'enhancing': {2: [38]},
#  'guards': {2: [74], 3: [121], 5: [62]},
#  'Last': {4: [37]},
#  'infrastructure': {1: [31, 67], 2: [69, 93], 3: [92], 9: [115]},
#  'leaders': {0: [90]},
#  'last': {0: [63], 4: [9], 9: [36]},
#  'Tennessee': {9: [48]},
#  'small': {1: [120], 2: [96], 4: [87]},
#  "document's": {7: [57]},
#  'selected': {1: [70], 2: [84, 100], 3: [95], 9: [118]},
#  'ignored': {0: [8]},
#  'subset': {8: [91]},
#  'many': {5: [90], 8: [64]},
#  'searching': {7: [44], 8: [107]},
#  'engines': {7: [1, 75], 8: [18, 58]},
#  'camouflage': {8: [76]},
#  'captain': {9: [44]},
#  'vote': {0: [108]},
#  'friend': {9: [11]},
#  'need': {3: [46]},
#  'already': {8: [102]},
#  'intelligent': {1: [163]},
#  'Health': {1: [99], 9: [143]},
#  'sign': {9: [85]},
#  'originally': {9: [2]},
#  'took': {4: [55]},
#  'May': {9: [58]},
#  'end': {2: [87], 3: [33]},
#  'course': {1: [32]},
#  'Moreover': {7: [43]},
#  'spamming': {7: [51]},
#  'Earlier': {1: [170]},
#  'named': {4: [1]},
#  'champion': {9: [55]},
#  'example': {0: [40], 8: [15]},
#  'five': {4: [22]},
#  'services': {1: [44, 79], 2: [106], 3: [109], 9: [97, 127]},
#  'travelers': {3: [14, 38]},
#  'popularity': {8: [5]},
#  'document': {2: [18, 25, 34], 7: [23, 30]},
#  'strong': {1: [54], 2: [61, 116], 3: [125], 9: [107]},
#  'time': {0: [113], 1: [107], 5: [29], 6: [14], 9: [151]},
#  'programmers': {1: [189]},
#  'however': {6: [1], 8: [53, 113]},
#  'hours': {3: [53]},
#  'tools': {1: [38, 76], 9: [124]},
#  'Envisioned': {1: [18]},
#  'traditionally': {8: [47]},
#  'integrate': {1: [131]},
#  'aunt': {4: [54]},
#  'loans': {1: [119], 2: [95], 4: [86]},
#  'allow': {8: [85]},
#  'alone': {3: [8]},
#  'understanding': {1: [161]},
#  'smooth': {6: [6]},
#  'program': {1: [22, 46, 58, 136, 151, 183, 205],
#   2: [65, 108, 120],
#   3: [114, 133],
#   9: [99, 111]},
#  'Republicans': {0: [49]},
#  'cake': {9: [61]},
#  'quality': {2: [58], 7: [42], 8: [54, 66]},
#  'vulnerable': {7: [50]},
#  'passengers': {3: [45]},
#  'difficult': {0: [103]},
#  'empower': {1: [11]},
#  'GOP': {0: [102]},
#  'tomorrow': {1: [112, 150], 3: [98], 9: [156]},
#  'changes': {0: [14]},
#  'appreciation': {4: [58]},
#  'relevancy': {7: [49]},
#  'precision': {8: [49]},
#  'months': {6: [4, 32]},
#  'information': {7: [87], 8: [111, 123]},
#  'continues': {0: [82]},
#  'Iraqis': {5: [71]},
#  'corrupt': {5: [5]},
#  'University': {9: [47]},
#  'figure': {3: [28]},
#  'Information': {8: [44]},
#  'beginning': {7: [29]},
#  'Azure': {1: [77, 89], 9: [125, 133]},
#  'showing': {4: [45]},
#  'close': {7: [26]},
#  'include': {7: [21]},
#  'according': {4: [60], 7: [13]},
#  'ago': {3: [27]},
#  'often': {7: [66], 8: [51, 115]},
#  'identified': {3: [73]},
#  'ever': {1: [128]},
#  'calculated': {2: [19, 26]},
#  'critical': {1: [127]},
#  'performance': {2: [39]},
#  'query': {7: [72]},
#  'AI': {1: [2, 15, 30, 43, 61, 74, 78, 104, 124, 134, 178, 193, 210, 217],
#   2: [68, 105, 123],
#   3: [108, 136],
#   9: [96, 114, 122, 126, 148, 164]},
#  'praying': {4: [48]},
#  'produced': {8: [56]},
#  'relief': {0: [37], 4: [66], 5: [4]},
#  'evictions': {4: [81]},
#  'giant': {1: [48], 2: [110], 3: [116], 9: [101]},
#  'Republican': {0: [89], 5: [6]},
#  '2007': {5: [72]},
#  'bill': {0: [15, 38]},
#  'moves': {5: [92]},
#  'world': {2: [11, 51], 8: [23]},
#  'appeals': {7: [69]},
#  'Learning': {1: [91], 9: [135]},
#  'seen': {9: [33]},
#  'Machine': {1: [90], 9: [134]},
#  'season': {4: [24]},
#  'skills': {1: [17, 155, 188, 192, 218]},
#  'hold': {0: [53], 6: [57]},
#  'Mr': {9: [25, 31]},
#  'goes': {5: [74]},
#  'require': {1: [113, 116], 3: [99], 9: [157, 160]},
#  'looked': {1: [158], 3: [129], 6: [60], 9: [5]},
#  'national': {9: [54]},
#  'collaborations': {1: [117], 9: [161]},
#  'General': {1: [96], 9: [140]},
#  'stir': {9: [30]},
#  'Groves': {9: [1, 40, 77]},
#  'Hub': {1: [9, 25, 69], 2: [83, 99], 3: [94], 9: [117]},
#  'photo': {1: [80], 2: [75], 4: [39, 56]},
#  'Although': {7: [31, 73]},
#  'act': {6: [16]},
#  'laundering': {2: [50], 3: [85], 5: [25]},
#  'respond': {0: [2]},
#  'officials': {3: [31]},
#  'numbers': {8: [7]},
#  'followed': {9: [9]},
#  'messaging': {0: [48]},
#  'failed': {6: [35]},
#  'considered': {7: [70]},
#  'rhetoric': {0: [100]},
#  'presidential': {5: [3, 83]},
#  'hundreds': {8: [72]},
#  'protests': {9: [69]},
#  'boarding': {3: [54]},
#  'importance': {2: [2]},
#  'Chris': {5: [26]},
#  'Heritage': {9: [22]},
#  'rushed': {4: [14]},
#  'drive': {9: [8]},
#  'begging': {0: [105]},
#  'connected': {1: [165]},
#  'sentenced': {5: [46]},
#  'Gigabytes': {8: [43]},
#  'citations': {2: [10]},
#  'build': {1: [1, 53, 144, 153, 216], 2: [60, 115], 3: [124], 9: [106]},
#  'flight': {3: [55, 67]},
#  'contacted': {6: [45]},
#  'surveillance': {1: [64], 2: [72, 126], 3: [79, 139]},
#  'hands': {1: [200]},
#  'home': {3: [41]},
#  'present': {7: [7]},
#  'recall': {8: [50]},
#  'expressed': {4: [31]},
#  'sent': {9: [3]},
#  'particularly': {2: [36]},
#  'Act': {0: [69]},
#  'expand': {1: [50], 2: [112], 3: [118], 9: [103]},
#  'interregnum': {6: [7]},
#  'strategy': {6: [53], 7: [32]},
#  'Perdue': {0: [0, 72]},
#  'football': {4: [51]},
#  'taxes': {5: [55]},
#  'better': {7: [36]},
#  'later': {3: [100], 9: [18]},
#  'Pac': {4: [2]},
#  'systems': {8: [46]},
#  'expense': {0: [33]},
#  'worrying': {3: [30]},
#  'Matter': {9: [92]},
#  'come': {0: [107]},
#  'curriculum': {1: [34]},
#  'retain': {0: [57]},
#  'PCR': {3: [48]},
#  'used': {8: [20]},
#  'funding': {4: [77]},
#  'grow': {5: [76]},
#  'announced': {1: [6, 174], 3: [43]},
#  'begin': {3: [39]},
#  'expire': {4: [82]},
#  'draw': {7: [60]},
#  'hone': {1: [191]},
#  'techniques': {7: [5, 52], 8: [84, 97, 114]},
#  'excess': {8: [41]},
#  'even': {6: [2]},
#  'cause': {9: [28]},
#  'institutions': {1: [29, 130]},
#  'Jordan': {1: [81], 2: [76], 4: [0, 40]},
#  'order': {0: [31], 7: [59], 8: [79]},
#  'days': {0: [44]},
#  'craft': {0: [51]},
#  'holiday': {2: [88], 3: [34]},
#  'remains': {3: [29]},
#  'receiving': {9: [35]},
#  'government': {4: [76]},
#  'challenge': {1: [138], 3: [111], 6: [38]},
#  'well': {1: [204], 8: [108]},
#  'player': {1: [83], 2: [78], 4: [42]},
#  'Floyd': {9: [75]},
#  'weeks': {5: [78]},
#  'ranking': {7: [37]},
#  'viral': {4: [44]},
#  'airports': {3: [6]},
#  'rally': {9: [87]},
#  'high': {4: [49]},
#  'inflate': {7: [56]},
#  'Covid': {3: [88], 6: [23]},
#  'citing': {2: [22]},
#  'seats': {0: [56]},
#  'CDC': {3: [42, 68]},
#  'yards': {4: [16]},
#  'Defense': {0: [67]},
#  'launched': {1: [10], 6: [33]},
#  'next': {1: [12, 219], 4: [83], 9: [67]},
#  'whose': {2: [54], 9: [50]},
#  'lives': {1: [109], 9: [153]},
#  'Freshman': {4: [6]},
#  'common': {8: [83]},
#  'reigning': {9: [53]},
#  'status': {0: [5]},
#  'jump': {2: [33]},
#  'kneeling': {4: [47]},
#  'several': {6: [34]},
#  'per': {8: [35]},
#  'Mesquite': {4: [12]},
#  'Instagram': {9: [79]},
#  'balloons': {9: [63]},
#  'urged': {9: [81]},
#  'cheer': {9: [43, 51]},
#  'Texas': {4: [13]},
#  'among': {1: [146], 3: [102], 9: [20]},
#  'prison': {5: [50]},
#  'sure': {5: [75]},
#  'parents': {9: [59]},
#  'witness': {5: [53]},
#  'support': {1: [26, 36], 9: [89]},
#  'job': {1: [186]},
#  'revived': {4: [89]},
#  'total': {3: [23]},
#  'lengthy': {5: [65]},
#  'country': {6: [20]},
#  'conceived': {7: [80]},
#  'containing': {2: [9]},
#  'designed': {7: [76]},
#  'permit': {9: [17]},
#  'content': {1: [33]},
#  'April': {1: [171]},
#  'space': {7: [17]},
#  'popular': {8: [27]},
#  'measure': {7: [48]},
#  'attending': {9: [46]},
#  'George': {9: [74]},
#  'would': {0: [21, 29]},
#  'introduced': {8: [118]},
#  "CNN's": {0: [3]},
#  'administered': {0: [91]},
#  'checks': {0: [25]},
#  'relatively': {7: [40]},
#  'businesses': {1: [121], 2: [97], 4: [88]},
#  'working': {1: [123], 9: [163]},
#  'probability': {2: [29], 3: [104]},
#  'conspiracy': {5: [13, 31]},
#  'presidency': {0: [45, 79]},
#  'online': {1: [197]},
#  'money': {2: [49], 3: [84], 5: [24]},
#  '597': {4: [15]},
#  'father': {5: [41]},
#  'focused': {1: [209]},
#  '72': {3: [52]},
#  'company': {1: [72, 173], 9: [120]},
#  'representing': {2: [28], 3: [103]},
#  'required': {2: [92], 3: [63]},
#  'execute': {8: [31]},
#  'classified': {8: [103]},
#  'access': {1: [41], 2: [103], 3: [106], 9: [94]},
#  'ruses': {7: [78]},
#  'developed': {1: [184]},
#  'relevance': {7: [58]},
#  'Hunter': {5: [9]},
#  'disappointing': {7: [83]},
#  'retaliating': {5: [51]},
#  'accommodate': {0: [32]},
#  'behavior': {0: [42]},
#  'jobs': {1: [111], 3: [97], 9: [155]},
#  'Kyle': {4: [29]},
#  'idea': {0: [23]},
#  "Trump's": {0: [12, 34]},
#  'specified': {8: [90]},
#  'entertaining': {0: [114]},
#  'negative': {3: [47]},
#  'try': {6: [48]},
#  'voter': {6: [30]},
#  'unwanted': {8: [74]},
#  'spot': {0: [104]},
#  'remaining': {6: [13]},
#  'control': {0: [58]},
#  'earlier': {3: [70]},
#  '600': {4: [91]},
#  'claims': {0: [116], 6: [29]},
#  'yet': {3: [91]},
#  'day': {3: [25], 8: [36]},
#  'attempt': {1: [0, 137], 6: [37, 56], 7: [6]},
#  '12': {4: [3]},
#  'rigged': {6: [69]},
#  'trial': {5: [66]},
#  'much': {9: [29]},
#  "learner's": {9: [16]},
#  'setting': {0: [74]},
#  'pandemic': {3: [12], 6: [25]},
#  'top': {5: [93]},
#  'Cloud': {1: [8, 24]},
#  'Services': {1: [86, 88], 9: [130, 132]},
#  'help': {1: [215]},
#  'false': {5: [36], 6: [28]},
#  'ecosystem': {1: [56], 2: [63, 118], 3: [131], 9: [109]},
#  'lull': {3: [37]},
#  'team': {9: [52, 57]},
#  'wide': {2: [12, 52], 8: [24]},
#  'Charles': {5: [39]},
#  'post': {9: [80]},
#  'ready': {1: [3, 16, 187]},
#  'inadvertently': {8: [124]},
#  'effective': {8: [98, 116]},
#  'veto': {0: [77]},
#  'educators': {1: [147]},
#  'useful': {2: [37]},
#  'recently': {7: [22], 8: [9]},
#  'public': {1: [182], 9: [78]},
#  'cloud': {1: [42, 133, 164], 2: [104], 3: [107], 9: [95]},
#  'rush': {2: [90], 3: [36]},
#  'planning': {1: [52], 2: [59, 114], 3: [120], 9: [105]},
#  'around': {1: [27]},
#  'constrain': {8: [87]},
#  'ranked': {7: [12]},
#  'lawsuits': {6: [36]},
#  'constraint': {8: [117]},
#  'waning': {0: [43]},
#  'variant': {3: [72]},
#  'Election': {5: [58]},
#  'science': {1: [195]},
#  'also': {0: [81], 1: [206], 2: [79], 3: [122], 5: [1, 63], 6: [44]},
#  'lost': {0: [95]},
#  'randomly': {2: [32]},
#  'intervene': {6: [50]},
#  'India': {1: [57, 102], 2: [64, 119], 3: [132], 9: [110, 146]},
#  'people': {3: [4, 20], 8: [8], 9: [82]},
#  'rife': {0: [119]},
#  'vetoed': {0: [65]},
#  'baseless': {0: [115]},
#  'attention': {7: [61]},
#  'defining': {1: [105], 9: [149]},
#  'unsigned': {4: [69]},
#  'election': {0: [93], 1: [139], 3: [112], 6: [39, 68]},
#  'circulated': {3: [101], 9: [19]},
#  '30': {8: [32]},
#  'scope': {5: [88], 8: [88]},
#  'including': {2: [47], 3: [82], 5: [22]},
#  'test': {3: [50, 65]},
#  'Black': {9: [90]},
#  'bigger': {0: [24]},
#  'Georgia': {0: [86]},
#  'authors': {7: [53]},
#  'Utah': {4: [25]},
#  'managed': {6: [11]},
#  '500': {8: [42]},
#  'something': {9: [88]},
#  'wanted': {1: [190]},
#  'Duncan': {5: [8]},
#  'funds': {5: [16]},
#  'prior': {3: [66]},
#  'possible': {0: [76]},
#  "Jordan's": {4: [53]},
#  'huge': {8: [13]},
#  'searches': {8: [34, 69]},
#  'eliminated': {8: [125]},
#  'celebrated': {9: [60]},
#  'avoid': {7: [77]},
#  'data': {1: [194]},
#  'included': {1: [207]},
#  'power': {1: [157], 3: [128], 6: [59]},
#  'educate': {1: [148]},
#  'calls': {0: [13]},
#  'development': {1: [37, 75], 9: [123]},
#  'large': {2: [56], 8: [6]},
#  'Airlines': {2: [91], 3: [62]},
#  'advertisements': {7: [62]},
#  'database': {2: [6, 7, 15, 31], 8: [92, 100]},
#  'laboratory': {3: [60]},
#  'Player': {4: [7]},
#  'game': {4: [23, 52]},
#  'antigen': {3: [49]},
#  'Monday': {4: [79]},
#  'Commission': {5: [59]},
#  'According': {1: [92], 9: [136]},
#  'widely': {4: [62]},
#  'additional': {8: [94]},
#  'supported': {0: [73]},
#  'subsets': {8: [104]},
#  'nation': {9: [71]},
#  'maintain': {6: [65]},
#  'failures': {7: [84]},
#  'Four': {5: [60]},
#  'b': {7: [25]},
#  '469': {3: [19]},
#  'judged': {8: [48]},
#  'desperate': {6: [62]},
#  'Snapchat': {9: [12]},
#  'donate': {9: [84]},
#  'databases': {2: [44], 8: [14, 60]},
#  'record': {3: [11]},
#  'rank': {2: [16, 24]},
#  'variation': {2: [57]},
#  'one': {0: [39]},
#  'training': {1: [122], 9: [162]},
#  'wants': {1: [49], 2: [111], 3: [117], 9: [102]},
#  'million': {3: [3], 8: [33]},
#  'signals': {0: [36]},
#  'media': {4: [65]},
#  'camera': {9: [6]},
#  'careful': {0: [47]},
#  'onto': {0: [54], 1: [156], 3: [127], 6: [58]},
#  'majority': {0: [59]},
#  'Joe': {0: [98]},
#  'moratorium': {4: [80]},
#  'shared': {4: [63]},
#  'developing': {1: [162]},
#  'Federal': {5: [57]},
#  'mechanisms': {7: [81]},
#  'reason': {7: [63]},
#  'vector': {7: [16]},
#  'Wednesday': {0: [18], 3: [7]},
#  'hypermedia': {2: [14, 43]},
#  'states': {6: [43]},
#  'slur': {9: [10]},
#  'track': {1: [180]},
#  'computer': {8: [2]},
#  'Saturday': {0: [7], 4: [36, 75]},
#  'set': {1: [59, 143], 2: [66, 121], 3: [134], 9: [112]},
#  '616': {3: [18]},
#  'results': {1: [140],
#   2: [42],
#   3: [61, 113],
#   6: [40],
#   7: [35, 38, 65],
#   8: [55, 82, 127]},
#  'travel': {2: [89], 3: [10, 35]},
#  'unjustifiable': {5: [91]},
#  'sweeping': {9: [70]},
#  'Currently': {8: [26]},
#  'coming': {5: [77]},
#  'Christmas': {3: [16]},
#  'questions': {0: [9]},
#  'air': {3: [9]},
#  'legislatures': {6: [47]},
#  'package': {0: [28], 4: [67]},
#  'commit': {5: [32]},
#  'Even': {6: [52]},
#  'gotten': {9: [15]},
#  'fraud': {0: [120], 2: [48], 3: [83], 5: [23, 34], 6: [31]},
#  'voting': {0: [84, 117]},
#  'size': {8: [40]},
#  'core': {1: [60], 2: [67, 122], 3: [135], 9: [113]},
#  'ones': {8: [78]},
#  'relevant': {7: [8], 8: [77]},
#  'KXII': {4: [61]},
#  'variations': {7: [14, 19]},
#  'felonies': {2: [46], 3: [81], 5: [21]},
#  'run': {4: [74]},
#  'documentation': {3: [59]},
#  'Ms': {9: [0, 39, 76]},
#  'system': {0: [85, 118], 1: [65], 2: [73, 127], 3: [86, 140]},
#  '23': {3: [22]},
#  'rushing': {4: [19]},
#  'different': {1: [114], 9: [158]},
#  'low': {7: [41], 8: [65]},
#  'known': {8: [109]},
#  'entire': {8: [22]},
#  'Senate': {0: [61]},
#  'securities': {5: [33]},
#  'benefits': {4: [73]},
#  'six': {4: [18]},
#  'November': {0: [92]},
#  'educational': {1: [129]},
#  'state': {0: [94], 6: [46]},
#  'turns': {6: [0]},
#  'misuse': {5: [14]},
#  'payments': {4: [92]},
#  '19': {3: [89], 6: [24]},
#  'Trump': {0: [62, 80], 5: [0, 79], 6: [10, 26]},
#  'workforce': {1: [4, 149]},
#  'petition': {9: [86]},
#  'campaign': {0: [1], 5: [15]},
#  'swing': {6: [42]},
#  'result': {7: [82], 8: [68]},
#  'left': {0: [101], 4: [68]},
#  'IoT': {1: [68], 2: [82, 98], 3: [93], 9: [116]},
#  'developer': {1: [35, 55, 208], 2: [62, 117], 3: [126], 9: [108]},
#  'campuses': {1: [71], 2: [85, 101], 3: [96], 9: [119]},
#  'established': {1: [66], 2: [81], 3: [87]},
#  'evidence': {6: [67]},
#  'official': {9: [65]},
#  'certain': {4: [93]},
#  'Manish': {1: [93], 9: [137]},
#  'School': {9: [24]},
#  'PS': {1: [98], 9: [142]},
#  'serving': {5: [28]},
#  'irrelevant': {8: [73]},
#  'represents': {3: [21]},
#  'updated': {7: [24]},
#  'cases': {8: [99, 105, 112]},
#  'key': {6: [41]},
#  'cognitive': {1: [154]},
#  'applications': {1: [167]},
#  'conference': {0: [17]},
#  'touchdowns': {4: [20]},
#  'cut': {0: [30]},
#  'erratic': {0: [41]},
#  'students': {1: [14, 40], 2: [102], 3: [105], 9: [21]},
#  'Blackwater': {5: [61]},
#  'method': {2: [0, 35]},
#  'credible': {6: [66]},
#  'indexable': {8: [37]},
#  'parts': {0: [27]},
#  'screened': {3: [5, 15, 24]},
#  'sequencing': {3: [74]},
#  'Americans': {4: [94]},
#  'protest': {9: [83]},
#  'direct': {4: [90]},
#  'specific': {8: [110]},
#  'documents': {2: [8, 21, 55], 7: [9, 11], 8: [61, 67, 75]},
#  'orange': {9: [62]},
#  'signal': {2: [86], 3: [32]},
#  'number': {2: [45], 3: [13, 80], 5: [20]},
#  'color': {9: [66]},
#  'solutions': {1: [166]},
#  'learning': {1: [179]},
#  'law': {5: [43]},
#  'Due': {8: [0]},
#  'attended': {9: [27]},
#  'user': {8: [86, 106, 119]},
#  'reach': {1: [51], 2: [113], 3: [119], 9: [104]},
#  'offered': {5: [2]},
#  'ravaged': {6: [22]},
#  'featured': {1: [199]},
#  'went': {4: [43]},
#  'week': {0: [64], 3: [71], 4: [10, 84]},
#  'labs': {1: [201]},
#  'lapse': {4: [78]},
#  'deep': {4: [33]},
#  'homogeneous': {8: [101]},
#  'Steve': {5: [17]},
#  'still': {6: [21], 7: [39]},
#  'argued': {0: [26]},
#  'web': {2: [13, 53], 7: [47], 8: [25, 39, 62]},
#  'political': {6: [17]},
#  'news': {0: [16]},
#  'month': {1: [220], 9: [68]},
#  'chances': {8: [121]},
#  'video': {9: [4, 34]},
#  'improve': {8: [80]},
#  'killing': {5: [69], 9: [73]},
#  'artificially': {7: [55]},
#  'son': {5: [42]},
#  'runoffs': {0: [110]},
#  'UK': {3: [56]},
#  'gesture': {4: [59]},
#  'making': {5: [35]},
#  'Whittingham': {4: [30]},
#  'senator': {0: [10]},
#  'Typically': {7: [10]},
#  'internet': {8: [16]},
#  'Offensive': {4: [5]},
#  'assigns': {2: [1]},
#  'increase': {8: [4]},
#  'ranks': {2: [3, 20]},
#  'Lives': {9: [91]},
#  'Bot': {1: [87], 9: [131]},
#  'Kushner': {5: [40, 45]},
#  'supporters': {0: [106]},
#  'three': {1: [19]},
#  'selectivity': {8: [81]},
#  'said': {0: [20], 1: [103], 3: [69], 9: [7, 147]},
#  'typically': {8: [70]},
#  'expanded': {4: [71]},
#  'decisions': {5: [89]},
#  'retrieval': {8: [45]},
#  'Intelligent': {1: [7, 23]},
#  'Thursday': {3: [44]},
#  'delayed': {4: [95]},
#  'developments': {8: [1]},
#  'proved': {6: [54]},
#  'new': {1: [132]},
#  'freshman': {9: [14]},
#  'Biden': {0: [99]},
#  'increasingly': {1: [159], 3: [130], 6: [61]},
#  'competitive': {7: [46]},
#  'legislation': {0: [70]},
#  'January': {0: [111]},
#  'increases': {8: [120]},
#  '2': {3: [2]},
#  'efforts': {3: [75]},
#  'Year': {4: [8]},
#  'lying': {5: [56]},
#  '14': {5: [70]},
#  'statement': {4: [35], 5: [37]},
#  'Nearly': {3: [0]},
#  'assets': {1: [214]},
#  'Professional': {1: [176]},
#  'Collins': {5: [27]},
#  'might': {8: [30]},
#  'seniors': {9: [41]},
#  'social': {4: [64]},
#  'expert': {1: [202]},
#  'skillset': {1: [115], 9: [159]},
#  'undermine': {0: [83]},
#  'various': {7: [4]},
#  'search': {2: [40],
#   7: [27, 34, 64, 74],
#   8: [12, 17, 21, 28, 57, 89, 95, 126]},
#  'open': {0: [22], 1: [181]},
#  'shortened': {4: [21]},
#  'institutional': {1: [142]},
#  'constant': {2: [27]},
#  'continued': {6: [64]},
#  'override': {0: [78]},
#  'charges': {5: [30]},
#  'within': {3: [51]}}

# %%
words["results"]
# Out:
# {1: [140], 2: [42], 3: [61, 113], 6: [40], 7: [35, 38, 65], 8: [55, 82, 127]}

# %% [markdown]
# <a id='Phrase_query'></a>
# > ### Phrase query

# %%
def phrase_query(query):
    queryList = regexp_tokenize(query, "[\w']+")
    documentList = []
    flag = 0
    # get Posting List for  evry Word 
    for word in queryList:
        try:
            documentList.append(list(words[word].keys()))
        except:
            return -1
        
    # get intersection Documents between words
    intersectDocs = documentList[0]
    for i in range(1,len(documentList)):
        intersectDocs =  list( set(intersectDocs).intersection(documentList[i]) )
        flag = 1
    
     
    if flag == 1:
        # Validate indexing
        query_intersection = {}
        query_Notintersection = {}
        for Docnum in intersectDocs:
            indexsList = []
            for word in queryList :
                indexsList.append(words[word][Docnum] )
            for i in range(1,len(indexsList)): # change range(1,len(intersectIndex)) with k 
                indexsList[i] = list(np.asarray(indexsList[i]) - i)
                
            # get intersection Index between Words 
            intersectIndexs = indexsList[0]
            for i in range(1,len(indexsList)):
                intersectIndexs = list( set(intersectIndexs).intersection(indexsList[i]) )
                
            # save intersections 
            if len(intersectIndexs) > 0:
                query_intersection[Docnum]=[]
                for i in range(0,len(queryList)): # change range(1,len(queryList)) with k 
                    query_intersection[Docnum].append(list(np.asarray(intersectIndexs)+i))
            else:
                query_Notintersection[Docnum]=[]
                for i in range(0,len(indexsList)): # change range(1,len(queryList)) with k
                    query_Notintersection[Docnum].append(indexsList[i])
        return query_intersection,query_Notintersection
                               
    else:
        return intersectDocs

# %%
phrase_query("package left    unsigned   President")
# Out:
# ({4: [[67], [68], [69], [70]]}, {})

# %%
#search
term = "search"
print("<{} {}".format(term,len(words[term])))
for key, value in words[term].items():
    print('  ',key, ' : ', value)
# Out:
# <search 3
#    2  :  [40]
#    7  :  [27, 34, 64, 74]
#    8  :  [12, 17, 21, 28, 57, 89, 95, 126]

# %% [markdown]
# <a id='vector_space_model'></a>
# ## Vector Space Model

# %% [markdown]
# ![title](TFIDFEqutions.jpg)

# %%
import math

# %%
documentListTill3 = Cleaned_tokenized_documentList[:3]
len(documentListTill3)
# Out:
# 3

# %% [markdown]
# <a id='term_frequency'></a>
# > ### Term Frequency

# %%
def tf(term,document):
    i=0
    for word in document:
        if word == term:
            i+=1
    return i

# %%
def creat_tfMatrix(uniqueWords, docNum):
    Tf_Idf_Matrix = pd.DataFrame( columns = ['term', 'tf'])
    for term in uniqueWords:
        new_row = {'term':term,'tf':tf(term,documentListTill3[docNum])}
        Tf_Idf_Matrix = Tf_Idf_Matrix.append(new_row, ignore_index=True)
    return Tf_Idf_Matrix

# %%
# create Unique Words 
uniqueWords = []
for doc in documentListTill3:
    uniqueWords += list(set(doc))
uniqueWords = list(set(uniqueWords))
len(uniqueWords)
# Out:
# 314

# %%
# First Document 
Tf_Idf_Matrix1 = creat_tfMatrix(uniqueWords, 0)

# %%
# Second Document 
Tf_Idf_Matrix2 = creat_tfMatrix(uniqueWords, 1)

# %%
# third Document 
Tf_Idf_Matrix3 = creat_tfMatrix(uniqueWords, 2)

# %%
Tf_Idf_Matrix2
# Out:
#             term tf
# 0        support  2
# 1            job  1
# 2          elect  0
# 3      Wednesday  0
# 4     generation  1
# ..           ... ..
# 309      program  7
# 310          Joe  0
# 311  Republicans  0
# 312      quality  0
# 313   developing  1
#
# [314 rows x 2 columns]

# %% [markdown]
# <a id='idf'></a>
# > ### inverse document frequency

# %% [markdown]
# ![title](IDFEqution.jpg)

# %%
# Create DF 
def create_df(uniqueWords,documentList):
    df={}
    for term in uniqueWords:
        df[term]=0
        for document in documentList:
            if term in document:
                df[term]+=1
    return df

# %%
# Create IDF 
def create_Idf(df, N):
    Idf={}
    for term in uniqueWords:
        Idf[term]=format(math.log10(N/df[term]), '.3f')
    return Idf

# %%
df  = create_df(uniqueWords, documentListTill3)
idf = create_Idf(df,3)
idf
# Out:
# {'support': '0.477',
#  'job': '0.477',
#  'elect': '0.477',
#  'Wednesday': '0.477',
#  'generation': '0.477',
#  'hypermedia': '0.477',
#  'difficult': '0.477',
#  'empower': '0.477',
#  'GOP': '0.477',
#  'tomorrow': '0.477',
#  'track': '0.477',
#  'changes': '0.477',
#  'Saturday': '0.477',
#  'transforming': '0.477',
#  'set': '0.176',
#  'Education': '0.477',
#  'continues': '0.477',
#  'industry': '0.477',
#  'results': '0.176',
#  'travel': '0.477',
#  'containing': '0.477',
#  'fight': '0.477',
#  'first': '0.477',
#  'content': '0.477',
#  'April': '0.477',
#  'questions': '0.477',
#  'Azure': '0.477',
#  'browser': '0.477',
#  'package': '0.477',
#  'technology': '0.477',
#  'depth': '0.477',
#  'would': '0.477',
#  'Country': '0.477',
#  'ever': '0.477',
#  "CNN's": '0.477',
#  'ramp': '0.477',
#  'courses': '0.477',
#  'calculated': '0.477',
#  'administered': '0.477',
#  'become': '0.477',
#  'across': '0.477',
#  'checks': '0.477',
#  'businesses': '0.176',
#  'working': '0.477',
#  'critical': '0.477',
#  'fraud': '0.176',
#  'voting': '0.477',
#  'school': '0.477',
#  'performance': '0.477',
#  'Prakash': '0.477',
#  'AI': '0.176',
#  'probability': '0.477',
#  'relief': '0.477',
#  'presidency': '0.477',
#  'core': '0.176',
#  'online': '0.477',
#  'money': '0.477',
#  'year': '0.477',
#  'giant': '0.176',
#  'technologies': '0.477',
#  'Republican': '0.477',
#  'Loeffler': '0.477',
#  'focused': '0.477',
#  'felonies': '0.477',
#  'system': '0.000',
#  'bill': '0.477',
#  'company': '0.477',
#  'different': '0.477',
#  'world': '0.477',
#  'representing': '0.477',
#  'Senate': '0.477',
#  'required': '0.477',
#  'interrupting': '0.477',
#  'Learning': '0.477',
#  'access': '0.176',
#  'Machine': '0.477',
#  'skills': '0.477',
#  'nodes': '0.477',
#  'hold': '0.477',
#  'Cognitive': '0.477',
#  'November': '0.477',
#  'developed': '0.477',
#  'educational': '0.477',
#  'state': '0.477',
#  'require': '0.477',
#  'accommodate': '0.477',
#  'looked': '0.477',
#  'behavior': '0.477',
#  'jobs': '0.477',
#  'collaborations': '0.477',
#  'Trump': '0.477',
#  'workforce': '0.477',
#  'General': '0.477',
#  'capabilities': '0.477',
#  'Hub': '0.176',
#  '100': '0.477',
#  'idea': '0.477',
#  "Trump's": '0.477',
#  'campaign': '0.477',
#  'instructors': '0.477',
#  'photo': '0.176',
#  'inquiries': '0.477',
#  'left': '0.477',
#  'respond': '0.477',
#  'entertaining': '0.477',
#  'IoT': '0.176',
#  'relentlessly': '0.477',
#  'developer': '0.176',
#  'messaging': '0.477',
#  'campuses': '0.176',
#  'established': '0.176',
#  'Program': '0.477',
#  'rhetoric': '0.477',
#  'spot': '0.477',
#  'control': '0.477',
#  'engine': '0.477',
#  'claims': '0.477',
#  'Manish': '0.477',
#  'attempt': '0.477',
#  'PS': '0.477',
#  'President': '0.477',
#  'trying': '0.477',
#  'setting': '0.477',
#  'Cloud': '0.477',
#  'importance': '0.477',
#  'Services': '0.477',
#  'help': '0.477',
#  'assigned': '0.477',
#  'US': '0.000',
#  'series': '0.477',
#  'collaborative': '0.477',
#  'ecosystem': '0.176',
#  'begging': '0.477',
#  'wide': '0.477',
#  'National': '0.477',
#  'connected': '0.477',
#  'opposing': '0.176',
#  'ready': '0.477',
#  'cognitive': '0.477',
#  'citations': '0.477',
#  'build': '0.176',
#  'conference': '0.477',
#  'applications': '0.477',
#  'cut': '0.477',
#  'veto': '0.477',
#  'erratic': '0.477',
#  'students': '0.176',
#  'educators': '0.477',
#  'method': '0.477',
#  'useful': '0.477',
#  'parts': '0.477',
#  'surveillance': '0.176',
#  'hands': '0.477',
#  'public': '0.477',
#  'cloud': '0.176',
#  'two': '0.477',
#  'rush': '0.477',
#  'linked': '0.477',
#  'documents': '0.477',
#  'planning': '0.176',
#  'signal': '0.477',
#  'around': '0.477',
#  'number': '0.477',
#  'pardoned': '0.477',
#  'solutions': '0.477',
#  'waning': '0.477',
#  '5': '0.477',
#  'provide': '0.477',
#  'learning': '0.477',
#  'Microsoft': '0.477',
#  'ad': '0.477',
#  'federal': '0.176',
#  'Act': '0.477',
#  'expand': '0.176',
#  'aims': '0.477',
#  'attack': '0.477',
#  'Perdue': '0.477',
#  'Manager': '0.477',
#  'science': '0.477',
#  'provided': '0.477',
#  'also': '0.000',
#  "That's": '0.477',
#  'mixed': '0.477',
#  'reach': '0.176',
#  'featured': '0.477',
#  'week': '0.477',
#  'lost': '0.477',
#  'labs': '0.477',
#  'expense': '0.477',
#  'addition': '0.477',
#  'randomly': '0.477',
#  'stands': '0.477',
#  'come': '0.477',
#  'curriculum': '0.477',
#  'India': '0.176',
#  'rife': '0.477',
#  'argued': '0.477',
#  'vetoed': '0.477',
#  'part': '0.176',
#  'web': '0.477',
#  'news': '0.477',
#  'retain': '0.477',
#  'month': '0.477',
#  'baseless': '0.477',
#  'give': '0.477',
#  'laundering': '0.477',
#  'defining': '0.477',
#  'Authorization': '0.477',
#  'election': '0.176',
#  'announced': '0.477',
#  'Redmond': '0.176',
#  'runoffs': '0.477',
#  'bunch': '0.477',
#  'could': '0.176',
#  'senator': '0.477',
#  'hone': '0.477',
#  'enhancing': '0.477',
#  'including': '0.477',
#  'guards': '0.477',
#  'infrastructure': '0.176',
#  'leaders': '0.477',
#  'bigger': '0.477',
#  'last': '0.477',
#  'Georgia': '0.477',
#  'assigns': '0.477',
#  'small': '0.176',
#  'selected': '0.176',
#  'ignored': '0.477',
#  'ranks': '0.477',
#  'Bot': '0.477',
#  'wanted': '0.477',
#  'institutions': '0.477',
#  'supporters': '0.477',
#  'possible': '0.477',
#  'three': '0.477',
#  'Jordan': '0.176',
#  'particularly': '0.477',
#  'said': '0.176',
#  'order': '0.477',
#  'vote': '0.477',
#  'days': '0.477',
#  'craft': '0.477',
#  'Intelligent': '0.477',
#  'intelligent': '0.477',
#  'Health': '0.477',
#  'holiday': '0.477',
#  'data': '0.477',
#  'new': '0.477',
#  'included': '0.477',
#  'end': '0.477',
#  'power': '0.477',
#  'challenge': '0.477',
#  'Biden': '0.477',
#  'well': '0.477',
#  'course': '0.477',
#  'educate': '0.477',
#  'calls': '0.477',
#  'development': '0.477',
#  'legislation': '0.477',
#  'increasingly': '0.477',
#  'player': '0.176',
#  'large': '0.477',
#  'Airlines': '0.477',
#  'database': '0.477',
#  'Earlier': '0.477',
#  'January': '0.477',
#  'According': '0.477',
#  'example': '0.477',
#  'seats': '0.477',
#  'citing': '0.477',
#  'Defense': '0.477',
#  'supported': '0.477',
#  'services': '0.176',
#  'launched': '0.477',
#  'next': '0.477',
#  'among': '0.477',
#  'whose': '0.477',
#  'lives': '0.477',
#  'document': '0.477',
#  'strong': '0.176',
#  'Professional': '0.477',
#  'assets': '0.477',
#  'time': '0.176',
#  'programmers': '0.477',
#  'status': '0.477',
#  'jump': '0.477',
#  'expert': '0.477',
#  'databases': '0.477',
#  'tools': '0.477',
#  'skillset': '0.477',
#  'undermine': '0.477',
#  'rank': '0.477',
#  'variation': '0.477',
#  'one': '0.477',
#  'Envisioned': '0.477',
#  'open': '0.176',
#  'training': '0.477',
#  'signals': '0.477',
#  'wants': '0.176',
#  'integrate': '0.477',
#  'loans': '0.176',
#  'search': '0.477',
#  'institutional': '0.477',
#  'careful': '0.477',
#  'onto': '0.176',
#  'majority': '0.477',
#  'understanding': '0.477',
#  'override': '0.477',
#  'constant': '0.477',
#  'program': '0.176',
#  'Joe': '0.477',
#  'Republicans': '0.477',
#  'quality': '0.477',
#  'developing': '0.477'}

# %% [markdown]
# <a id='tf_idf_matrix'></a>
# > ### Tf_Idf_Matrix

# %% [markdown]
# #### Creat TF Weight

# %% [markdown]
# ![title](tf_weight.jpg)

# %%
# Create TF Weight
def creat_TF_Weight(Tf_Idf_Matrix):
    TF_Weightlist = []
    for tf in Tf_Idf_Matrix.tf.values:
        if tf != 0:
            TF_Weightlist.append(  1+math.log10(tf))
        else:
            TF_Weightlist.append(0)
    return TF_Weightlist

# %%
# First Document 
Tf_Idf_Matrix1['tf_weight'] = creat_TF_Weight(Tf_Idf_Matrix1);

# %%
# Second Document 
Tf_Idf_Matrix2['tf_weight'] = creat_TF_Weight(Tf_Idf_Matrix2);

# %%
# third Document 
Tf_Idf_Matrix3['tf_weight'] = creat_TF_Weight(Tf_Idf_Matrix3);

# %%
Tf_Idf_Matrix2
# Out:
#             term tf  tf_weight
# 0        support  2   1.301030
# 1            job  1   1.000000
# 2          elect  0   0.000000
# 3      Wednesday  0   0.000000
# 4     generation  1   1.000000
# ..           ... ..        ...
# 309      program  7   1.845098
# 310          Joe  0   0.000000
# 311  Republicans  0   0.000000
# 312      quality  0   0.000000
# 313   developing  1   1.000000
#
# [314 rows x 3 columns]

# %% [markdown]
# #### Creat TF-IDF

# %% [markdown]
# ![title](TF_IDF.jpg)

# %%
# Creat TF-IDF
def creat_TF_IDF(Tf_Idf_Matrix,idf):
    TF_IDFlist = []
    TF_Weight = list(Tf_Idf_Matrix.tf_weight.values)
    IDF = list(idf.values())
    for i in range(len(IDF)):
        TF_IDFlist.append(TF_Weight[i]*float(IDF[i]))
    return TF_IDFlist

# %%
# First Document 
Tf_Idf_Matrix1['tf_idf'] = creat_TF_IDF(Tf_Idf_Matrix1,idf);

# %%
# Second Document
Tf_Idf_Matrix2['tf_idf'] = creat_TF_IDF(Tf_Idf_Matrix2,idf);

# %%
# third Document 
Tf_Idf_Matrix3['tf_idf'] = creat_TF_IDF(Tf_Idf_Matrix3,idf);

# %%
Tf_Idf_Matrix2
# Out:
#             term tf  tf_weight    tf_idf
# 0        support  2   1.301030  0.620591
# 1            job  1   1.000000  0.477000
# 2          elect  0   0.000000  0.000000
# 3      Wednesday  0   0.000000  0.000000
# 4     generation  1   1.000000  0.477000
# ..           ... ..        ...       ...
# 309      program  7   1.845098  0.324737
# 310          Joe  0   0.000000  0.000000
# 311  Republicans  0   0.000000  0.000000
# 312      quality  0   0.000000  0.000000
# 313   developing  1   1.000000  0.477000
#
# [314 rows x 4 columns]

# %% [markdown]
# ##### Creat Normalize

# %%
# Create Length
def creat_length(Tf_Idf_Matrix):
    tf_idfSquare = 0
    for tf_idf in Tf_Idf_Matrix.tf_idf.values:
        tf_idfSquare += (tf_idf*tf_idf)
    return math.sqrt(tf_idfSquare)

# %%
# First Document 
lengthD1 = creat_length(Tf_Idf_Matrix1)

# %%
# Second Document
lengthD2 = creat_length(Tf_Idf_Matrix2)

# %%
# third Document 
lengthD3 = creat_length(Tf_Idf_Matrix3)

# %%
# Create normalize
def creat_normalize(Tf_Idf_Matrix,length):
    normalizelist = []
    for tf_idf in Tf_Idf_Matrix.tf_idf.values:
        normalizelist.append(tf_idf/length)
    return normalizelist

# %%
# First Document 
Tf_Idf_Matrix1['normalize'] = creat_normalize(Tf_Idf_Matrix1,lengthD1);

# %%
# Second Document
Tf_Idf_Matrix2['normalize'] = creat_normalize(Tf_Idf_Matrix2,lengthD2);

# %%
# third Document 
Tf_Idf_Matrix3['normalize'] = creat_normalize(Tf_Idf_Matrix3,lengthD3);

# %%
Tf_Idf_Matrix2
# Out:
#             term tf  tf_weight    tf_idf  normalize
# 0        support  2   1.301030  0.620591   0.110016
# 1            job  1   1.000000  0.477000   0.084561
# 2          elect  0   0.000000  0.000000   0.000000
# 3      Wednesday  0   0.000000  0.000000   0.000000
# 4     generation  1   1.000000  0.477000   0.084561
# ..           ... ..        ...       ...        ...
# 309      program  7   1.845098  0.324737   0.057568
# 310          Joe  0   0.000000  0.000000   0.000000
# 311  Republicans  0   0.000000  0.000000   0.000000
# 312      quality  0   0.000000  0.000000   0.000000
# 313   developing  1   1.000000  0.477000   0.084561
#
# [314 rows x 5 columns]

# %% [markdown]
# <a id='Similarity'></a>
# > ### Similarity between query and each document

# %%
# Create Tf Idf Matrix for  the query
def create_TFIDFMatrixQuery(query,documentListTill3):
    queryList = regexp_tokenize(query, "[\w']+")
    documentListTill3.append(queryList)
    # Create TF Matrix 
    queryTf_Idf_Matrix = creat_tfMatrix(uniqueWords, 3)
    # Create TF Weight
    queryTf_Idf_Matrix['tf_weight'] = creat_TF_Weight(queryTf_Idf_Matrix)
    # Create TF-IDF
    queryTf_Idf_Matrix['tf_idf'] = creat_TF_IDF(queryTf_Idf_Matrix,idf);
    # Create Length
    querylengthD = creat_length(queryTf_Idf_Matrix)
    # Create normalize
    queryTf_Idf_Matrix['normalize'] = creat_normalize(queryTf_Idf_Matrix,querylengthD)
    documentListTill3 = documentListTill3[:-1]
    return queryTf_Idf_Matrix

# %%
queryTf_Idf_Matrix = create_TFIDFMatrixQuery("job Wednesday hypermedia access",documentListTill3)
# Out:
#             term tf
# 0        support  0
# 1            job  1
# 2          elect  0
# 3      Wednesday  1
# 4     generation  0
# ..           ... ..
# 309      program  0
# 310          Joe  0
# 311  Republicans  0
# 312      quality  0
# 313   developing  0
#
# [314 rows x 2 columns]

# %%
queryTf_Idf_Matrix
# Out:
#             term tf  tf_weight  tf_idf  normalize
# 0        support  0        0.0   0.000    0.00000
# 1            job  1        1.0   0.477    0.56468
# 2          elect  0        0.0   0.000    0.00000
# 3      Wednesday  1        1.0   0.477    0.56468
# 4     generation  0        0.0   0.000    0.00000
# ..           ... ..        ...     ...        ...
# 309      program  0        0.0   0.000    0.00000
# 310          Joe  0        0.0   0.000    0.00000
# 311  Republicans  0        0.0   0.000    0.00000
# 312      quality  0        0.0   0.000    0.00000
# 313   developing  0        0.0   0.000    0.00000
#
# [314 rows x 5 columns]

# %%
# Calculate Similarity
def similarity(queryTf_Idf_Matrix,documentTf_Idf_Matrix):
    querynormalize    = list(queryTf_Idf_Matrix['normalize'].values)
    documentnormalize = list(documentTf_Idf_Matrix['normalize'].values)
    result = 0
    for i in range(len(querynormalize)):
        result += querynormalize[i]*documentnormalize[i]
    return result

# %%
print( "query similarity With Document1 is: ",similarity(queryTf_Idf_Matrix,Tf_Idf_Matrix1) )
print( "query similarity With Document2 is: ",similarity(queryTf_Idf_Matrix,Tf_Idf_Matrix2) )
print( "query similarity With Document3 is: ",similarity(queryTf_Idf_Matrix,Tf_Idf_Matrix3) )
# Out:
# query similarity With Document1 is:  0.05407387310571205
# query similarity With Document2 is:  0.05425034834813515
# query similarity With Document3 is:  0.0988644865895887
